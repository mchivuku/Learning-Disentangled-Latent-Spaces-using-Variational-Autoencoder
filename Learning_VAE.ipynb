# %% [markdown]
# <a href="https://colab.research.google.com/github/mchivuku/csb659-project/blob/master/Learning_VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Learning VAE

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My\ Drive/Masters-DS/CSCI-B659/project/vae-model1
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Masters-DS/CSCI-B659/project/vae-model1

# %%
# %%capture
# !pip install tqdm six

# %% [markdown]
# ## Load Libraries

# %%
from glob import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil
from torchvision import transforms
from torchvision import models
import torchvision
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch.optim import lr_scheduler
from torch import optim
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
import time
from torchvision import datasets,transforms
import torch.nn.functional as F
import torch.optim as optim


import os
from torchvision.utils import save_image

## Plotting library

from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
import cv2
from scipy.stats import norm
from sklearn import manifold

plt.style.use('fivethirtyeight')
# %matplotlib inline

print('Torch', torch.__version__, 'CUDA', torch.version.cuda)
print('Device:', torch.device('cuda:0'))
print(torch.cuda.is_available())

is_cuda = torch.cuda.is_available()
device = torch.device ( "cuda:0" if torch.cuda.is_available () else "cpu" )
# Out:
# Torch 1.0.1.post2 CUDA 10.0.130
# Device: cuda:0
# True

# %% [markdown]
# ## Some Utilities - to visualize

# %%
## Show image
def imshow(img,title=None):
  """Imshow for Tensor."""
  img = img.numpy().transpose((1,2,0))
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  img = std * img + mean # normalize
  img = np.clip(img, 0, 1) # clip image
  plt.figure(figsize=(16,4))
  plt.axis('off')
  plt.imshow(img)
  
  if title is not None:
    plt.title(title)         
  
def plot_grid(inputs):
  # Make a grid from batch 
  out = torchvision.utils.make_grid(inputs,10,10)
  imshow(out, title="")

# %% [markdown]
# ## Metric

# %%
### Metrics - Base Class For all Metrics
class Metric:
  def __init__(self):
    pass
  def __call__(self, outputs, target, loss):
    raise NotImplementedError
    
  def reset(self):
    raise NotImplementedError
    
  def value(self):
    raise NotImplementedError
    
  def name(self):
    raise NotImplementedError
    
## Accuracy Metric
class AccumulatedAccuracyMetric(Metric):
  def __init__(self):
      self.correct = 0
      self.total = 0
      
  def __call__(self, outputs, target):
      # Track the accuracy
      _, argmax = torch.max(outputs, 1)
      accuracy = (target == argmax.squeeze()).float().sum()
      self.correct += accuracy 
      self.total += target.size(0)
      return self.value()
  
  def reset(self):
      self.correct = 0
      self.total = 0

  def value(self):
      return 100 * float(self.correct) / self.total

  def name(self):
      return 'Accuracy'
    
    
## Loss
class RunningAverage ():
    """A simple class that maintains the running average of a quantity
    Example:
    ```
    loss_avg = RunningAverage()
    loss_avg.update(2)
    loss_avg.update(4)
    loss_avg() = 3
    ```
    """

    def __init__( self ):
        self.steps = 0
        self.total = 0

    def update( self, val ):
        self.total += val
        self.steps += 1

    def __call__( self ):
        return self.total / float ( self.steps )
      
      
      
"""
Directory to store results

"""
      
def make_results(dir):
  if os.path.isdir(dir):
    shutil.rmtree(dir)
  os.makedirs(dir)

# %% [markdown]
# ## Load Data

# %%
path="/content/drive/My Drive/Masters-DS/Deep Learning - E533/Homework3/"

transformation = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
train_dataset = datasets.MNIST(os.path.join(path,"MNIST/data"),train=True,transform=transformation,download=True)
test_dataset = datasets.MNIST(os.path.join(path,"MNIST/data"),train=False,transform=transformation,download=True)
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=128,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset,batch_size=128,shuffle=True)

## Test TSNE plot for reconstrunction on 1000 test samples
testing_tsne = torch.utils.data.DataLoader(train_dataset,batch_size=len(train_dataset),shuffle=True)
test_data, test_labels = next(iter(testing_tsne))[:1000]

# %%
print(f"Total number of train images: {len(train_dataset)}, total number of test images: {len(test_dataset)}, total number of train batches: {len(train_loader)}")
# Out:
# Total number of train images: 60000, total number of test images: 10000, total number of train batches: 469

# %% [markdown]
# ## Models

# %% [markdown]
# ### Encoder Network

# %%
class Encoder(nn.Module):
  def __init__(self, nb_latents):
    super(Encoder,self).__init__()
    
    ## Netwrok
    self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
    self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        
        
    self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        
    self.conv4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=2, stride=1),
            nn.ReLU())
        
    self.fc1 = nn.Linear(1024, 256)
        
    self.fc_mean = nn.Linear(256, nb_latents)
    self.fc_std = nn.Linear(256, nb_latents)
    
    self.relu = nn.ReLU()
    self.sigmoid = nn.Sigmoid()
    
  def forward(self,x):
    x = (self.conv1(x))
    x =  (self.conv2(x))
    x =  (self.conv3(x))
    x =  (self.conv4(x))
    x = x.reshape(x.size(0), -1)
    x = self.relu(self.fc1(x))
    return self.fc_mean(x), self.fc_std(x)

# %% [markdown]
# ### Decoder

# %%
class Decoder(nn.Module):
  def __init__(self,nb_latents):
    super(Decoder, self).__init__()
    
    self.fc1 = nn.Linear(nb_latents, 256)
    self.fc2 = nn.Linear(256, 1024)
        
        
        
    self.fc3 = nn.Linear(1024,7*7*64)
        
    self.deconv1 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
    self.deconv2 = nn.ConvTranspose2d(32, 1, kernel_size=2, stride=2)
    
    self.relu = nn.ReLU()
    self.sigmoid = nn.Sigmoid()
    
  def forward(self, z):
    x = self.relu(self.fc1(z))
    x = self.relu(self.fc2(x))
    x = self.relu(self.fc3(x))
    x = self.relu(self.deconv1(x.view(-1, 64, 7, 7)))
    x = self.deconv2(x)
    return self.sigmoid(x)

# %% [markdown]
# ### Classifier

# %%
class Classifier(nn.Module):
  def __init__(self,nb_latents):
    super(Classifier,self).__init__()
    
    ## Define NN - 5 hidden layers 1024 hidden units
    self.fc1 = nn.Linear(nb_latents, 1024)
    self.fc2 = nn.Linear(1024, 1024)
    self.fc3 = nn.Linear(1024, 10)
    
  
  def forward(self,x):
    ## flat input features
    x = x.view(-1, self.num_flat_features(x))
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
   
    
    x = self.fc3(x)
    
    return F.log_softmax(x, dim=1)  
  
  def num_flat_features(self,x):
    size = x.size()[1:] # all dimensions except the batch dimension
    num_features = 1
    for s in size:
      num_features *=s
    return num_features

# %% [markdown]
# ### VAE Network

# %%
class VAE(nn.Module):
  def __init__(self,nb_latents):
    super(VAE,self).__init__()
    
    self.encoder = Encoder(nb_latents)
    self.decoder = Decoder(nb_latents)
    
    ## Classifier
    #self.classifier = Classifier()
   
  def reparameterize(self, mu, logvar):
    std = logvar.mul(0.5).exp_()
    eps = Variable(std.data.new(std.size()).normal_())
    return eps.mul(std).add_(mu)
    
  def forward(self, x):
    mu, logvar = self.encoder(x)
    z = self.reparameterize(mu, logvar)
    return self.decoder(z), mu, logvar
  
  
  def encode(self,x):
    mu, logvar = self.encoder(x)
    return mu, logvar
    
  def decode(self,x):
    return self.decoder(x)

# %%
### Loss Function
def loss_function(recon_x, x, mu, logvar,beta=1):
  """
  Reconstruction loss  + KL divergence loss over all elements of the batch
  """
  bce = F.binary_cross_entropy(recon_x, x.view(-1, 28*28), size_average=False)
  
  kld = -0.5* (1+ logvar -mu.pow(2) -  logvar.exp())
  return kld.mean(dim = 0), bce + beta*kld.sum()

# %%
nb_latents = 20
model = VAE(nb_latents)
if is_cuda:
  model = model.to(device)

print(model)

optimizer = optim.Adam(model.parameters(), lr=1e-3)
# Out:
# VAE(
#   (encoder): Encoder(
#     (conv1): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (conv3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (conv4): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(2, 2), stride=(1, 1))
#       (1): ReLU()
#     )
#     (fc1): Linear(in_features=1024, out_features=256, bias=True)
#     (fc_mean): Linear(in_features=256, out_features=20, bias=True)
#     (fc_std): Linear(in_features=256, out_features=20, bias=True)
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
#   (decoder): Decoder(
#     (fc1): Linear(in_features=20, out_features=256, bias=True)
#     (fc2): Linear(in_features=256, out_features=1024, bias=True)
#     (fc3): Linear(in_features=1024, out_features=3136, bias=True)
#     (deconv1): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (deconv2): ConvTranspose2d(32, 1, kernel_size=(2, 2), stride=(2, 2))
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
# )

# %% [markdown]
# ## Traverse Latent Space

# %%
import os
#os.makedirs("traverse")
 

"""
Traverse Latents
"""
def traverse_latents(model, datapoint, nb_latents, epoch, batch_idx, dirpath="traverse"):
  model.eval()
  datapoint = datapoint.to(device)
  if isinstance(model,VAE):
    datapoint = datapoint.unsqueeze(0)
    mu, _ = model.encode(datapoint)
  else:
    mu, _ = model.encode(datapoint.view(-1))
  
  recons = torch.zeros((7, nb_latents, 28, 28))
  for zi in range(nb_latents):
    muc = mu.squeeze().clone()
    for i, val in enumerate(np.linspace(-3, 3, 7)):
      muc[zi] = val
      
      recon = model.decode(muc).cpu()
      recons[i, zi] = recon.view(28, 28)

  filename = os.path.join(dirpath, 'traversal_' + str(epoch) + '_' + str(batch_idx) + '.png')
  save_image(recons.view(-1, 1, 28, 28), filename, nrow=nb_latents, pad_value=1)

# %% [markdown]
# ## Train Epoch

# %%
log_interval = 1
save_interval = 1
testpoint = torch.Tensor(train_loader.dataset[0][0]).to(device)
def train_epoch(epoch):
  model.train()
  
  for batch_idx, (data, labels) in enumerate(train_loader):
    data = data.to(device)
    labels = labels.to(device)
    
    
    batch_size = data.size(0)

    recon_batch, mu, logvar = model(data)
    
    kld, loss = loss_function(recon_batch.squeeze().view(-1,28*28), data, mu, logvar)
    ## parameter update
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
      
    
    
    loss /=len(data)
    
    if not batch_idx % log_interval:
      print("Epoch {}, batch: {}/{}, loss: {:.2f}".format(
              epoch, batch_idx, len(train_loader), loss))
      
    if not batch_idx % save_interval:
      traverse_latents(model, testpoint, nb_latents, epoch, batch_idx)
      model.train()

# %%
## Test Epoch
"""
Test
"""
def test_epoch(epoch):
    model.eval()
    test_loss = RunningAverage()
    
    ## Test reconstruction test
    testpoint = torch.Tensor(test_loader.dataset[0][0]).to(device)
  
    with torch.no_grad():
        for i, (data,labels) in enumerate(test_loader):
            data = data.to(device)
             
            batch_size = data.size(0)
            recon_batch, mu, logvar = model(data)
            
            ## Loss of VAE
            kld, loss = loss_function(recon_batch.squeeze().view(-1,28*28), data, mu, logvar)
            
            test_loss.update(loss.item() / len(data))
            
            if i % 200 == 0:
              ## test reconstruction
              n = min(data.size(0), 8)
              comparison = torch.cat([data[:n],recon_batch[:n]])
              save_image(comparison.cpu(),'./traverse/test_reconstruction_' + str(epoch) + '.png', nrow=n)
    
   
    return test_loss()

# %%
test_losses = []
for epoch in range(20):
  train_epoch(epoch)
  test_loss = test_epoch(epoch)
  message = 'Epoch: {}/{}. Test set: Average loss: {:.4f}'.format(epoch + 1, 20, test_loss)
  test_losses.append(test_loss)
  
  
  # Generate samples of reconstruction
  with torch.no_grad():
    sample = torch.randn(64, nb_latents).to(device)
    sample = model.decode(sample).cpu()
    save_image(sample.view(64, 1, 28, 28),
             'traverse/sample_' + str(epoch) + '.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0, batch: 0/469, loss: 531.84
# Epoch 0, batch: 1/469, loss: 516.91
# Epoch 0, batch: 2/469, loss: 500.65
# Epoch 0, batch: 3/469, loss: 479.07
# Epoch 0, batch: 4/469, loss: 446.33
# Epoch 0, batch: 5/469, loss: 396.92
# Epoch 0, batch: 6/469, loss: 322.94
# Epoch 0, batch: 7/469, loss: 184.02
# Epoch 0, batch: 8/469, loss: -82.04
# Epoch 0, batch: 9/469, loss: -718.85
# Epoch 0, batch: 10/469, loss: 19604.12
# Epoch 0, batch: 11/469, loss: -1875.36
# Epoch 0, batch: 12/469, loss: -1667.84
# Epoch 0, batch: 13/469, loss: -1410.67
# Epoch 0, batch: 14/469, loss: -1329.75
# Epoch 0, batch: 15/469, loss: -1339.09
# Epoch 0, batch: 16/469, loss: -1520.76
# Epoch 0, batch: 17/469, loss: -1483.04
# Epoch 0, batch: 18/469, loss: -1653.77
# Epoch 0, batch: 19/469, loss: -1896.60
# Epoch 0, batch: 20/469, loss: -1994.61
# Epoch 0, batch: 21/469, loss: -2394.48
# Epoch 0, batch: 22/469, loss: -2794.45
# Epoch 0, batch: 23/469, loss: -3179.57
# Epoch 0, batch: 24/469, loss: -3604.43
# Epoch 0, batch: 25/469, loss: -4112.63
# Epoch 0, batch: 26/469, loss: -4781.22
# Epoch 0, batch: 27/469, loss: -5367.51
# Epoch 0, batch: 28/469, loss: -6337.42
# Epoch 0, batch: 29/469, loss: -6793.43
# Epoch 0, batch: 30/469, loss: -7370.95
# Epoch 0, batch: 31/469, loss: -8063.89
# Epoch 0, batch: 32/469, loss: -8795.28
# Epoch 0, batch: 33/469, loss: -9337.94
# Epoch 0, batch: 34/469, loss: -9368.42
# Epoch 0, batch: 35/469, loss: -8766.49
# Epoch 0, batch: 36/469, loss: -8658.64
# Epoch 0, batch: 37/469, loss: -8114.59
# Epoch 0, batch: 38/469, loss: -7552.20
# Epoch 0, batch: 39/469, loss: -7604.44
# Epoch 0, batch: 40/469, loss: -7004.53
# Epoch 0, batch: 41/469, loss: -6990.12
# Epoch 0, batch: 42/469, loss: -6534.12
# Epoch 0, batch: 43/469, loss: -6125.06
# Epoch 0, batch: 44/469, loss: -6324.26
# Epoch 0, batch: 45/469, loss: -5946.66
# Epoch 0, batch: 46/469, loss: -5897.85
# Epoch 0, batch: 47/469, loss: -6153.92
# Epoch 0, batch: 48/469, loss: -6572.70
# Epoch 0, batch: 49/469, loss: -5824.96
# Epoch 0, batch: 50/469, loss: -6320.12
# Epoch 0, batch: 51/469, loss: -6368.66
# Epoch 0, batch: 52/469, loss: -6496.25
# Epoch 0, batch: 53/469, loss: -6593.09
# Epoch 0, batch: 54/469, loss: -6687.65
# Epoch 0, batch: 55/469, loss: -7136.35
# Epoch 0, batch: 56/469, loss: -7431.04
# Epoch 0, batch: 57/469, loss: -6844.58
# Epoch 0, batch: 58/469, loss: -7324.05
# Epoch 0, batch: 59/469, loss: -7736.54
# Epoch 0, batch: 60/469, loss: -7603.66
# Epoch 0, batch: 61/469, loss: -7367.42
# Epoch 0, batch: 62/469, loss: -7310.71
# Epoch 0, batch: 63/469, loss: -8090.41
# Epoch 0, batch: 64/469, loss: -7758.73
# Epoch 0, batch: 65/469, loss: -8198.88
# Epoch 0, batch: 66/469, loss: -7786.15
# Epoch 0, batch: 67/469, loss: -7435.46
# Epoch 0, batch: 68/469, loss: -7854.54
# Epoch 0, batch: 69/469, loss: -7947.39
# Epoch 0, batch: 70/469, loss: -7983.02
# Epoch 0, batch: 71/469, loss: -8249.42
# Epoch 0, batch: 72/469, loss: -7995.06
# Epoch 0, batch: 73/469, loss: -8185.20
# Epoch 0, batch: 74/469, loss: -8086.47
# Epoch 0, batch: 75/469, loss: -8377.08
# Epoch 0, batch: 76/469, loss: -8677.56
# Epoch 0, batch: 77/469, loss: -8220.96
# Epoch 0, batch: 78/469, loss: -8791.39
# Epoch 0, batch: 79/469, loss: -8823.64
# Epoch 0, batch: 80/469, loss: -8538.30
# Epoch 0, batch: 81/469, loss: -8193.17
# Epoch 0, batch: 82/469, loss: -8609.28
# Epoch 0, batch: 83/469, loss: -8064.21
# Epoch 0, batch: 84/469, loss: -7638.26
# Epoch 0, batch: 85/469, loss: -7429.11
# Epoch 0, batch: 86/469, loss: -7616.31
# Epoch 0, batch: 87/469, loss: -7540.56
# Epoch 0, batch: 88/469, loss: -7219.20
# Epoch 0, batch: 89/469, loss: -7756.09
# Epoch 0, batch: 90/469, loss: -7861.32
# Epoch 0, batch: 91/469, loss: -8169.96
# Epoch 0, batch: 92/469, loss: -8620.20
# Epoch 0, batch: 93/469, loss: -8453.75
# Epoch 0, batch: 94/469, loss: -8797.53
# Epoch 0, batch: 95/469, loss: -8228.91
# Epoch 0, batch: 96/469, loss: -8340.90
# Epoch 0, batch: 97/469, loss: -7986.40
# Epoch 0, batch: 98/469, loss: -7640.80
# Epoch 0, batch: 99/469, loss: -7616.47
# Epoch 0, batch: 100/469, loss: -7078.20
# Epoch 0, batch: 101/469, loss: -7286.33
# Epoch 0, batch: 102/469, loss: -7273.53
# Epoch 0, batch: 103/469, loss: -7658.14
# Epoch 0, batch: 104/469, loss: -7747.37
# Epoch 0, batch: 105/469, loss: -7433.41
# Epoch 0, batch: 106/469, loss: -7205.89
# Epoch 0, batch: 107/469, loss: -6749.71
# Epoch 0, batch: 108/469, loss: -6544.49
# Epoch 0, batch: 109/469, loss: -6664.15
# Epoch 0, batch: 110/469, loss: -6439.99
# Epoch 0, batch: 111/469, loss: -6765.83
# Epoch 0, batch: 112/469, loss: -6759.21
# Epoch 0, batch: 113/469, loss: -6793.99
# Epoch 0, batch: 114/469, loss: -6870.24
# Epoch 0, batch: 115/469, loss: -6567.28
# Epoch 0, batch: 116/469, loss: -6635.63
# Epoch 0, batch: 117/469, loss: -6889.10
# Epoch 0, batch: 118/469, loss: -6672.55
# Epoch 0, batch: 119/469, loss: -6588.88
# Epoch 0, batch: 120/469, loss: -6930.41
# Epoch 0, batch: 121/469, loss: -6806.53
# Epoch 0, batch: 122/469, loss: -6680.17
# Epoch 0, batch: 123/469, loss: -6853.97
# Epoch 0, batch: 124/469, loss: -6672.27
# Epoch 0, batch: 125/469, loss: -6462.39
# Epoch 0, batch: 126/469, loss: -6552.41
# Epoch 0, batch: 127/469, loss: -6988.31
# Epoch 0, batch: 128/469, loss: -7042.39
# Epoch 0, batch: 129/469, loss: -7266.96
# Epoch 0, batch: 130/469, loss: -7110.17
# Epoch 0, batch: 131/469, loss: -6974.68
# Epoch 0, batch: 132/469, loss: -6575.49
# Epoch 0, batch: 133/469, loss: -6599.15
# Epoch 0, batch: 134/469, loss: -6848.13
# Epoch 0, batch: 135/469, loss: -6874.00
# Epoch 0, batch: 136/469, loss: -7210.35
# Epoch 0, batch: 137/469, loss: -6810.96
# Epoch 0, batch: 138/469, loss: -7097.15
# Epoch 0, batch: 139/469, loss: -6873.06
# Epoch 0, batch: 140/469, loss: -7022.09
# Epoch 0, batch: 141/469, loss: -6794.91
# Epoch 0, batch: 142/469, loss: -6963.25
# Epoch 0, batch: 143/469, loss: -6613.98
# Epoch 0, batch: 144/469, loss: -6879.13
# Epoch 0, batch: 145/469, loss: -6951.95
# Epoch 0, batch: 146/469, loss: -6891.33
# Epoch 0, batch: 147/469, loss: -7021.28
# Epoch 0, batch: 148/469, loss: -6895.88
# Epoch 0, batch: 149/469, loss: -6869.36
# Epoch 0, batch: 150/469, loss: -6986.17
# Epoch 0, batch: 151/469, loss: -6866.76
# Epoch 0, batch: 152/469, loss: -6959.53
# Epoch 0, batch: 153/469, loss: -6878.11
# Epoch 0, batch: 154/469, loss: -6970.23
# Epoch 0, batch: 155/469, loss: -6930.68
# Epoch 0, batch: 156/469, loss: -7123.30
# Epoch 0, batch: 157/469, loss: -7045.23
# Epoch 0, batch: 158/469, loss: -7319.06
# Epoch 0, batch: 159/469, loss: -7158.93
# Epoch 0, batch: 160/469, loss: -7177.50
# Epoch 0, batch: 161/469, loss: -7202.30
# Epoch 0, batch: 162/469, loss: -7120.02
# Epoch 0, batch: 163/469, loss: -7158.26
# Epoch 0, batch: 164/469, loss: -7495.89
# Epoch 0, batch: 165/469, loss: -7662.92
# Epoch 0, batch: 166/469, loss: -7567.76
# Epoch 0, batch: 167/469, loss: -7371.68
# Epoch 0, batch: 168/469, loss: -7636.87
# Epoch 0, batch: 169/469, loss: -7709.16
# Epoch 0, batch: 170/469, loss: -7760.63
# Epoch 0, batch: 171/469, loss: -7836.97
# Epoch 0, batch: 172/469, loss: -7806.17
# Epoch 0, batch: 173/469, loss: -7893.36
# Epoch 0, batch: 174/469, loss: -7585.14
# Epoch 0, batch: 175/469, loss: -7592.29
# Epoch 0, batch: 176/469, loss: -7768.56
# Epoch 0, batch: 177/469, loss: -8236.76
# Epoch 0, batch: 178/469, loss: -7984.32
# Epoch 0, batch: 179/469, loss: -7996.10
# Epoch 0, batch: 180/469, loss: -7915.46
# Epoch 0, batch: 181/469, loss: -7616.68
# Epoch 0, batch: 182/469, loss: -7596.76
# Epoch 0, batch: 183/469, loss: -7741.58
# Epoch 0, batch: 184/469, loss: -7837.81
# Epoch 0, batch: 185/469, loss: -7323.42
# Epoch 0, batch: 186/469, loss: -7229.32
# Epoch 0, batch: 187/469, loss: -6895.78
# Epoch 0, batch: 188/469, loss: -6712.35
# Epoch 0, batch: 189/469, loss: -6825.83
# Epoch 0, batch: 190/469, loss: -6679.88
# Epoch 0, batch: 191/469, loss: -6441.35
# Epoch 0, batch: 192/469, loss: -6405.82
# Epoch 0, batch: 193/469, loss: -6585.78
# Epoch 0, batch: 194/469, loss: -6454.85
# Epoch 0, batch: 195/469, loss: -6582.36
# Epoch 0, batch: 196/469, loss: -6591.12
# Epoch 0, batch: 197/469, loss: -6277.86
# Epoch 0, batch: 198/469, loss: -6389.01
# Epoch 0, batch: 199/469, loss: -6618.48
# Epoch 0, batch: 200/469, loss: -6452.27
# Epoch 0, batch: 201/469, loss: -6419.73
# Epoch 0, batch: 202/469, loss: -6586.81
# Epoch 0, batch: 203/469, loss: -6301.55
# Epoch 0, batch: 204/469, loss: -6266.70
# Epoch 0, batch: 205/469, loss: -6389.48
# Epoch 0, batch: 206/469, loss: -6558.24
# Epoch 0, batch: 207/469, loss: -6578.93
# Epoch 0, batch: 208/469, loss: -6779.73
# Epoch 0, batch: 209/469, loss: -6432.11
# Epoch 0, batch: 210/469, loss: -6223.39
# Epoch 0, batch: 211/469, loss: -6541.84
# Epoch 0, batch: 212/469, loss: -6404.96
# Epoch 0, batch: 213/469, loss: -6425.85
# Epoch 0, batch: 214/469, loss: -6396.89
# Epoch 0, batch: 215/469, loss: -6176.44
# Epoch 0, batch: 216/469, loss: -6435.23
# Epoch 0, batch: 217/469, loss: -6508.48
# Epoch 0, batch: 218/469, loss: -6599.56
# Epoch 0, batch: 219/469, loss: -6533.55
# Epoch 0, batch: 220/469, loss: -6655.81
# Epoch 0, batch: 221/469, loss: -6439.97
# Epoch 0, batch: 222/469, loss: -6507.48
# Epoch 0, batch: 223/469, loss: -6612.48
# Epoch 0, batch: 224/469, loss: -6481.77
# Epoch 0, batch: 225/469, loss: -6649.21
# Epoch 0, batch: 226/469, loss: -6393.42
# Epoch 0, batch: 227/469, loss: -6248.75
# Epoch 0, batch: 228/469, loss: -6316.11
# Epoch 0, batch: 229/469, loss: -6583.13
# Epoch 0, batch: 230/469, loss: -6363.16
# Epoch 0, batch: 231/469, loss: -6341.58
# Epoch 0, batch: 232/469, loss: -6211.25
# Epoch 0, batch: 233/469, loss: -6303.44
# Epoch 0, batch: 234/469, loss: -6241.60
# Epoch 0, batch: 235/469, loss: -6488.46
# Epoch 0, batch: 236/469, loss: -6600.12
# Epoch 0, batch: 237/469, loss: -6225.42
# Epoch 0, batch: 238/469, loss: -6531.52
# Epoch 0, batch: 239/469, loss: -6488.07
# Epoch 0, batch: 240/469, loss: -6805.04
# Epoch 0, batch: 241/469, loss: -6927.98
# Epoch 0, batch: 242/469, loss: -6649.67
# Epoch 0, batch: 243/469, loss: -6592.67
# Epoch 0, batch: 244/469, loss: -6812.85
# Epoch 0, batch: 245/469, loss: -6536.61
# Epoch 0, batch: 246/469, loss: -6750.31
# Epoch 0, batch: 247/469, loss: -6683.44
# Epoch 0, batch: 248/469, loss: -6343.07
# Epoch 0, batch: 249/469, loss: -6575.26
# Epoch 0, batch: 250/469, loss: -6568.62
# Epoch 0, batch: 251/469, loss: -6844.39
# Epoch 0, batch: 252/469, loss: -6542.19
# Epoch 0, batch: 253/469, loss: -6616.26
# Epoch 0, batch: 254/469, loss: -6687.49
# Epoch 0, batch: 255/469, loss: -6674.18
# Epoch 0, batch: 256/469, loss: -6583.31
# Epoch 0, batch: 257/469, loss: -6674.18
# Epoch 0, batch: 258/469, loss: -6610.37
# Epoch 0, batch: 259/469, loss: -6547.50
# Epoch 0, batch: 260/469, loss: -6717.21
# Epoch 0, batch: 261/469, loss: -6681.94
# Epoch 0, batch: 262/469, loss: -6613.77
# Epoch 0, batch: 263/469, loss: -6751.49
# Epoch 0, batch: 264/469, loss: -6495.84
# Epoch 0, batch: 265/469, loss: -6931.02
# Epoch 0, batch: 266/469, loss: -6839.84
# Epoch 0, batch: 267/469, loss: -6931.15
# Epoch 0, batch: 268/469, loss: -6513.58
# Epoch 0, batch: 269/469, loss: -7020.52
# Epoch 0, batch: 270/469, loss: -6878.24
# Epoch 0, batch: 271/469, loss: -6152.61
# Epoch 0, batch: 272/469, loss: -6576.91
# Epoch 0, batch: 273/469, loss: -6931.41
# Epoch 0, batch: 274/469, loss: -6877.19
# Epoch 0, batch: 275/469, loss: -6924.98
# Epoch 0, batch: 276/469, loss: -6681.43
# Epoch 0, batch: 277/469, loss: -6627.86
# Epoch 0, batch: 278/469, loss: -6911.29
# Epoch 0, batch: 279/469, loss: -6896.41
# Epoch 0, batch: 280/469, loss: -6539.44
# Epoch 0, batch: 281/469, loss: -6764.50
# Epoch 0, batch: 282/469, loss: -6951.69
# Epoch 0, batch: 283/469, loss: -7017.82
# Epoch 0, batch: 284/469, loss: -6883.80
# Epoch 0, batch: 285/469, loss: -7044.60
# Epoch 0, batch: 286/469, loss: -6846.91
# Epoch 0, batch: 287/469, loss: -6753.69
# Epoch 0, batch: 288/469, loss: -6936.12
# Epoch 0, batch: 289/469, loss: -7044.58
# Epoch 0, batch: 290/469, loss: -6825.59
# Epoch 0, batch: 291/469, loss: -6841.94
# Epoch 0, batch: 292/469, loss: -6894.07
# Epoch 0, batch: 293/469, loss: -6714.36
# Epoch 0, batch: 294/469, loss: -6923.52
# Epoch 0, batch: 295/469, loss: -6856.05
# Epoch 0, batch: 296/469, loss: -6971.33
# Epoch 0, batch: 297/469, loss: -6571.06
# Epoch 0, batch: 298/469, loss: -6895.99
# Epoch 0, batch: 299/469, loss: -6843.26
# Epoch 0, batch: 300/469, loss: -6665.98
# Epoch 0, batch: 301/469, loss: -6673.38
# Epoch 0, batch: 302/469, loss: -6825.97
# Epoch 0, batch: 303/469, loss: -6974.00
# Epoch 0, batch: 304/469, loss: -7199.83
# Epoch 0, batch: 305/469, loss: -7105.55
# Epoch 0, batch: 306/469, loss: -6972.29
# Epoch 0, batch: 307/469, loss: -7264.28
# Epoch 0, batch: 308/469, loss: -7095.34
# Epoch 0, batch: 309/469, loss: -7013.63
# Epoch 0, batch: 310/469, loss: -7041.74
# Epoch 0, batch: 311/469, loss: -6902.32
# Epoch 0, batch: 312/469, loss: -6950.68
# Epoch 0, batch: 313/469, loss: -6997.89
# Epoch 0, batch: 314/469, loss: -7104.61
# Epoch 0, batch: 315/469, loss: -6801.00
# Epoch 0, batch: 316/469, loss: -7102.75
# Epoch 0, batch: 317/469, loss: -7203.76
# Epoch 0, batch: 318/469, loss: -6983.51
# Epoch 0, batch: 319/469, loss: -7077.62
# Epoch 0, batch: 320/469, loss: -6890.02
# Epoch 0, batch: 321/469, loss: -7173.35
# Epoch 0, batch: 322/469, loss: -7088.29
# Epoch 0, batch: 323/469, loss: -7219.68
# Epoch 0, batch: 324/469, loss: -7164.39
# Epoch 0, batch: 325/469, loss: -6947.07
# Epoch 0, batch: 326/469, loss: -6930.69
# Epoch 0, batch: 327/469, loss: -6943.87
# Epoch 0, batch: 328/469, loss: -7263.67
# Epoch 0, batch: 329/469, loss: -6983.03
# Epoch 0, batch: 330/469, loss: -7137.68
# Epoch 0, batch: 331/469, loss: -7235.81
# Epoch 0, batch: 332/469, loss: -7308.00
# Epoch 0, batch: 333/469, loss: -6931.82
# Epoch 0, batch: 334/469, loss: -6951.10
# Epoch 0, batch: 335/469, loss: -7184.73
# Epoch 0, batch: 336/469, loss: -6967.24
# Epoch 0, batch: 337/469, loss: -6915.83
# Epoch 0, batch: 338/469, loss: -7170.16
# Epoch 0, batch: 339/469, loss: -6977.11
# Epoch 0, batch: 340/469, loss: -7213.94
# Epoch 0, batch: 341/469, loss: -7118.59
# Epoch 0, batch: 342/469, loss: -7060.84
# Epoch 0, batch: 343/469, loss: -7033.95
# Epoch 0, batch: 344/469, loss: -7144.83
# Epoch 0, batch: 345/469, loss: -7241.56
# Epoch 0, batch: 346/469, loss: -6969.31
# Epoch 0, batch: 347/469, loss: -6925.79
# Epoch 0, batch: 348/469, loss: -6866.00
# Epoch 0, batch: 349/469, loss: -7204.84
# Epoch 0, batch: 350/469, loss: -7361.35
# Epoch 0, batch: 351/469, loss: -7165.06
# Epoch 0, batch: 352/469, loss: -7119.86
# Epoch 0, batch: 353/469, loss: -7230.30
# Epoch 0, batch: 354/469, loss: -7463.61
# Epoch 0, batch: 355/469, loss: -7118.63
# Epoch 0, batch: 356/469, loss: -7255.05
# Epoch 0, batch: 357/469, loss: -7338.81
# Epoch 0, batch: 358/469, loss: -7297.56
# Epoch 0, batch: 359/469, loss: -7366.56
# Epoch 0, batch: 360/469, loss: -7270.81
# Epoch 0, batch: 361/469, loss: -7488.04
# Epoch 0, batch: 362/469, loss: -7400.37
# Epoch 0, batch: 363/469, loss: -7069.68
# Epoch 0, batch: 364/469, loss: -7275.30
# Epoch 0, batch: 365/469, loss: -6985.85
# Epoch 0, batch: 366/469, loss: -7401.23
# Epoch 0, batch: 367/469, loss: -7287.64
# Epoch 0, batch: 368/469, loss: -7180.58
# Epoch 0, batch: 369/469, loss: -7126.83
# Epoch 0, batch: 370/469, loss: -7268.45
# Epoch 0, batch: 371/469, loss: -7597.46
# Epoch 0, batch: 372/469, loss: -7250.05
# Epoch 0, batch: 373/469, loss: -7126.02
# Epoch 0, batch: 374/469, loss: -7208.98
# Epoch 0, batch: 375/469, loss: -7365.88
# Epoch 0, batch: 376/469, loss: -7539.74
# Epoch 0, batch: 377/469, loss: -7238.25
# Epoch 0, batch: 378/469, loss: -7256.99
# Epoch 0, batch: 379/469, loss: -7205.71
# Epoch 0, batch: 380/469, loss: -7680.26
# Epoch 0, batch: 381/469, loss: -7570.38
# Epoch 0, batch: 382/469, loss: -7352.35
# Epoch 0, batch: 383/469, loss: -7483.70
# Epoch 0, batch: 384/469, loss: -7071.17
# Epoch 0, batch: 385/469, loss: -7186.79
# Epoch 0, batch: 386/469, loss: -7472.14
# Epoch 0, batch: 387/469, loss: -7229.17
# Epoch 0, batch: 388/469, loss: -7335.35
# Epoch 0, batch: 389/469, loss: -7423.10
# Epoch 0, batch: 390/469, loss: -7224.66
# Epoch 0, batch: 391/469, loss: -7424.11
# Epoch 0, batch: 392/469, loss: -7287.13
# Epoch 0, batch: 393/469, loss: -7460.78
# Epoch 0, batch: 394/469, loss: -7398.88
# Epoch 0, batch: 395/469, loss: -7484.75
# Epoch 0, batch: 396/469, loss: -7179.07
# Epoch 0, batch: 397/469, loss: -7139.26
# Epoch 0, batch: 398/469, loss: -7081.47
# Epoch 0, batch: 399/469, loss: -7554.01
# Epoch 0, batch: 400/469, loss: -7770.81
# Epoch 0, batch: 401/469, loss: -7293.57
# Epoch 0, batch: 402/469, loss: -7213.96
# Epoch 0, batch: 403/469, loss: -7406.95
# Epoch 0, batch: 404/469, loss: -7259.73
# Epoch 0, batch: 405/469, loss: -7479.85
# Epoch 0, batch: 406/469, loss: -7594.96
# Epoch 0, batch: 407/469, loss: -7677.99
# Epoch 0, batch: 408/469, loss: -7410.19
# Epoch 0, batch: 409/469, loss: -7321.29
# Epoch 0, batch: 410/469, loss: -7140.58
# Epoch 0, batch: 411/469, loss: -7426.05
# Epoch 0, batch: 412/469, loss: -7524.50
# Epoch 0, batch: 413/469, loss: -7679.16
# Epoch 0, batch: 414/469, loss: -7415.70
# Epoch 0, batch: 415/469, loss: -7176.13
# Epoch 0, batch: 416/469, loss: -7451.19
# Epoch 0, batch: 417/469, loss: -7456.43
# Epoch 0, batch: 418/469, loss: -7521.83
# Epoch 0, batch: 419/469, loss: -7505.95
# Epoch 0, batch: 420/469, loss: -7298.35
# Epoch 0, batch: 421/469, loss: -7068.21
# Epoch 0, batch: 422/469, loss: -7491.89
# Epoch 0, batch: 423/469, loss: -7576.36
# Epoch 0, batch: 424/469, loss: -7826.52
# Epoch 0, batch: 425/469, loss: -7470.82
# Epoch 0, batch: 426/469, loss: -7403.98
# Epoch 0, batch: 427/469, loss: -7394.28
# Epoch 0, batch: 428/469, loss: -7495.99
# Epoch 0, batch: 429/469, loss: -7492.94
# Epoch 0, batch: 430/469, loss: -7621.16
# Epoch 0, batch: 431/469, loss: -7624.42
# Epoch 0, batch: 432/469, loss: -7355.84
# Epoch 0, batch: 433/469, loss: -7373.76
# Epoch 0, batch: 434/469, loss: -7288.32
# Epoch 0, batch: 435/469, loss: -7664.13
# Epoch 0, batch: 436/469, loss: -7418.08
# Epoch 0, batch: 437/469, loss: -7513.21
# Epoch 0, batch: 438/469, loss: -7426.25
# Epoch 0, batch: 439/469, loss: -7416.30
# Epoch 0, batch: 440/469, loss: -7387.51
# Epoch 0, batch: 441/469, loss: -7334.33
# Epoch 0, batch: 442/469, loss: -7537.90
# Epoch 0, batch: 443/469, loss: -7691.07
# Epoch 0, batch: 444/469, loss: -7565.11
# Epoch 0, batch: 445/469, loss: -7202.76
# Epoch 0, batch: 446/469, loss: -7472.91
# Epoch 0, batch: 447/469, loss: -7474.49
# Epoch 0, batch: 448/469, loss: -7663.36
# Epoch 0, batch: 449/469, loss: -7640.02
# Epoch 0, batch: 450/469, loss: -7552.70
# Epoch 0, batch: 451/469, loss: -7422.05
# Epoch 0, batch: 452/469, loss: -7466.00
# Epoch 0, batch: 453/469, loss: -7556.41
# Epoch 0, batch: 454/469, loss: -7498.30
# Epoch 0, batch: 455/469, loss: -7339.27
# Epoch 0, batch: 456/469, loss: -7728.44
# Epoch 0, batch: 457/469, loss: -7200.85
# Epoch 0, batch: 458/469, loss: -7433.98
# Epoch 0, batch: 459/469, loss: -7628.27
# Epoch 0, batch: 460/469, loss: -7799.13
# Epoch 0, batch: 461/469, loss: -7667.52
# Epoch 0, batch: 462/469, loss: -7350.66
# Epoch 0, batch: 463/469, loss: -7493.07
# Epoch 0, batch: 464/469, loss: -7389.88
# Epoch 0, batch: 465/469, loss: -7345.87
# Epoch 0, batch: 466/469, loss: -7604.69
# Epoch 0, batch: 467/469, loss: -7308.74
# Epoch 0, batch: 468/469, loss: -7485.98
# Epoch 1, batch: 0/469, loss: -7350.15
# Epoch 1, batch: 1/469, loss: -7370.68
# Epoch 1, batch: 2/469, loss: -7512.51
# Epoch 1, batch: 3/469, loss: -7772.52
# Epoch 1, batch: 4/469, loss: -7678.49
# Epoch 1, batch: 5/469, loss: -7706.10
# Epoch 1, batch: 6/469, loss: -7378.01
# Epoch 1, batch: 7/469, loss: -7512.72
# Epoch 1, batch: 8/469, loss: -7742.68
# Epoch 1, batch: 9/469, loss: -7834.31
# Epoch 1, batch: 10/469, loss: -7502.42
# Epoch 1, batch: 11/469, loss: -7436.33
# Epoch 1, batch: 12/469, loss: -7418.21
# Epoch 1, batch: 13/469, loss: -7514.99
# Epoch 1, batch: 14/469, loss: -7443.65
# Epoch 1, batch: 15/469, loss: -7870.27
# Epoch 1, batch: 16/469, loss: -7667.35
# Epoch 1, batch: 17/469, loss: -7665.50
# Epoch 1, batch: 18/469, loss: -7609.74
# Epoch 1, batch: 19/469, loss: -7656.53
# Epoch 1, batch: 20/469, loss: -7609.69
# Epoch 1, batch: 21/469, loss: -7677.67
# Epoch 1, batch: 22/469, loss: -7749.01
# Epoch 1, batch: 23/469, loss: -7621.74
# Epoch 1, batch: 24/469, loss: -7740.99
# Epoch 1, batch: 25/469, loss: -7433.48
# Epoch 1, batch: 26/469, loss: -7792.71
# Epoch 1, batch: 27/469, loss: -7405.62
# Epoch 1, batch: 28/469, loss: -7841.15
# Epoch 1, batch: 29/469, loss: -7492.87
# Epoch 1, batch: 30/469, loss: -7635.82
# Epoch 1, batch: 31/469, loss: -7388.60
# Epoch 1, batch: 32/469, loss: -7634.10
# Epoch 1, batch: 33/469, loss: -7329.34
# Epoch 1, batch: 34/469, loss: -7667.44
# Epoch 1, batch: 35/469, loss: -7668.39
# Epoch 1, batch: 36/469, loss: -7744.82
# Epoch 1, batch: 37/469, loss: -7495.18
# Epoch 1, batch: 38/469, loss: -7518.72
# Epoch 1, batch: 39/469, loss: -7404.01
# Epoch 1, batch: 40/469, loss: -7287.05
# Epoch 1, batch: 41/469, loss: -7581.26
# Epoch 1, batch: 42/469, loss: -7786.90
# Epoch 1, batch: 43/469, loss: -7348.27
# Epoch 1, batch: 44/469, loss: -7156.50
# Epoch 1, batch: 45/469, loss: -7868.56
# Epoch 1, batch: 46/469, loss: -7307.12
# Epoch 1, batch: 47/469, loss: -7361.02
# Epoch 1, batch: 48/469, loss: -7062.20
# Epoch 1, batch: 49/469, loss: -7346.48
# Epoch 1, batch: 50/469, loss: -7230.98
# Epoch 1, batch: 51/469, loss: -7243.75
# Epoch 1, batch: 52/469, loss: -7279.40
# Epoch 1, batch: 53/469, loss: -7085.08
# Epoch 1, batch: 54/469, loss: -7163.39
# Epoch 1, batch: 55/469, loss: -7081.55
# Epoch 1, batch: 56/469, loss: -7282.57
# Epoch 1, batch: 57/469, loss: -7282.65
# Epoch 1, batch: 58/469, loss: -7287.74
# Epoch 1, batch: 59/469, loss: -7047.68
# Epoch 1, batch: 60/469, loss: -6963.96
# Epoch 1, batch: 61/469, loss: -6995.65
# Epoch 1, batch: 62/469, loss: -7129.74
# Epoch 1, batch: 63/469, loss: -7262.32
# Epoch 1, batch: 64/469, loss: -7274.98
# Epoch 1, batch: 65/469, loss: -7288.21
# Epoch 1, batch: 66/469, loss: -7379.37
# Epoch 1, batch: 67/469, loss: -7362.71
# Epoch 1, batch: 68/469, loss: -7132.98
# Epoch 1, batch: 69/469, loss: -7210.71
# Epoch 1, batch: 70/469, loss: -7250.92
# Epoch 1, batch: 71/469, loss: -7147.97
# Epoch 1, batch: 72/469, loss: -7309.07
# Epoch 1, batch: 73/469, loss: -7075.44
# Epoch 1, batch: 74/469, loss: -6856.92
# Epoch 1, batch: 75/469, loss: -7273.95
# Epoch 1, batch: 76/469, loss: -7041.36
# Epoch 1, batch: 77/469, loss: -6763.66
# Epoch 1, batch: 78/469, loss: -7150.01
# Epoch 1, batch: 79/469, loss: -7001.29
# Epoch 1, batch: 80/469, loss: -7213.54
# Epoch 1, batch: 81/469, loss: -6925.01
# Epoch 1, batch: 82/469, loss: -6948.41
# Epoch 1, batch: 83/469, loss: -7060.60
# Epoch 1, batch: 84/469, loss: -7360.61
# Epoch 1, batch: 85/469, loss: -6938.47
# Epoch 1, batch: 86/469, loss: -7095.18
# Epoch 1, batch: 87/469, loss: -7142.43
# Epoch 1, batch: 88/469, loss: -7283.36
# Epoch 1, batch: 89/469, loss: -7374.32
# Epoch 1, batch: 90/469, loss: -7128.31
# Epoch 1, batch: 91/469, loss: -7037.14
# Epoch 1, batch: 92/469, loss: -7055.35
# Epoch 1, batch: 93/469, loss: -7046.16
# Epoch 1, batch: 94/469, loss: -7166.77
# Epoch 1, batch: 95/469, loss: -7392.12
# Epoch 1, batch: 96/469, loss: -7043.37
# Epoch 1, batch: 97/469, loss: -6948.20
# Epoch 1, batch: 98/469, loss: -7097.83
# Epoch 1, batch: 99/469, loss: -6999.23
# Epoch 1, batch: 100/469, loss: -6918.80
# Epoch 1, batch: 101/469, loss: -6944.79
# Epoch 1, batch: 102/469, loss: -7041.65
# Epoch 1, batch: 103/469, loss: -6894.43
# Epoch 1, batch: 104/469, loss: -7001.41
# Epoch 1, batch: 105/469, loss: -6955.56
# Epoch 1, batch: 106/469, loss: -7020.55
# Epoch 1, batch: 107/469, loss: -6900.74
# Epoch 1, batch: 108/469, loss: -6737.71
# Epoch 1, batch: 109/469, loss: -7115.44
# Epoch 1, batch: 110/469, loss: -7188.67
# Epoch 1, batch: 111/469, loss: -7182.64
# Epoch 1, batch: 112/469, loss: -7196.25
# Epoch 1, batch: 113/469, loss: -7071.29
# Epoch 1, batch: 114/469, loss: -6842.16
# Epoch 1, batch: 115/469, loss: -7022.35
# Epoch 1, batch: 116/469, loss: -7065.61
# Epoch 1, batch: 117/469, loss: -7369.47
# Epoch 1, batch: 118/469, loss: -6997.16
# Epoch 1, batch: 119/469, loss: -6944.58
# Epoch 1, batch: 120/469, loss: -7007.09
# Epoch 1, batch: 121/469, loss: -7029.41
# Epoch 1, batch: 122/469, loss: -6976.93
# Epoch 1, batch: 123/469, loss: -7103.77
# Epoch 1, batch: 124/469, loss: -7135.11
# Epoch 1, batch: 125/469, loss: -7228.29
# Epoch 1, batch: 126/469, loss: -6988.24
# Epoch 1, batch: 127/469, loss: -7126.48
# Epoch 1, batch: 128/469, loss: -7118.38
# Epoch 1, batch: 129/469, loss: -7047.22
# Epoch 1, batch: 130/469, loss: -7120.10
# Epoch 1, batch: 131/469, loss: -7047.37
# Epoch 1, batch: 132/469, loss: -6981.08
# Epoch 1, batch: 133/469, loss: -6875.75
# Epoch 1, batch: 134/469, loss: -7148.08
# Epoch 1, batch: 135/469, loss: -6954.37
# Epoch 1, batch: 136/469, loss: -7204.20
# Epoch 1, batch: 137/469, loss: -7192.00
# Epoch 1, batch: 138/469, loss: -7458.36
# Epoch 1, batch: 139/469, loss: -7117.47
# Epoch 1, batch: 140/469, loss: -7094.92
# Epoch 1, batch: 141/469, loss: -6829.67
# Epoch 1, batch: 142/469, loss: -7118.02
# Epoch 1, batch: 143/469, loss: -7440.94
# Epoch 1, batch: 144/469, loss: -7232.12
# Epoch 1, batch: 145/469, loss: -7172.22
# Epoch 1, batch: 146/469, loss: -7246.41
# Epoch 1, batch: 147/469, loss: -7050.44
# Epoch 1, batch: 148/469, loss: -7222.26
# Epoch 1, batch: 149/469, loss: -6908.65
# Epoch 1, batch: 150/469, loss: -6975.40
# Epoch 1, batch: 151/469, loss: -7464.46
# Epoch 1, batch: 152/469, loss: -7149.41
# Epoch 1, batch: 153/469, loss: -7140.51
# Epoch 1, batch: 154/469, loss: -7085.68
# Epoch 1, batch: 155/469, loss: -7168.35
# Epoch 1, batch: 156/469, loss: -7278.09
# Epoch 1, batch: 157/469, loss: -7285.72
# Epoch 1, batch: 158/469, loss: -7176.82
# Epoch 1, batch: 159/469, loss: -7259.80
# Epoch 1, batch: 160/469, loss: -7315.81
# Epoch 1, batch: 161/469, loss: -7308.85
# Epoch 1, batch: 162/469, loss: -7381.62
# Epoch 1, batch: 163/469, loss: -7171.15
# Epoch 1, batch: 164/469, loss: -7372.99
# Epoch 1, batch: 165/469, loss: -7382.49
# Epoch 1, batch: 166/469, loss: -6983.22
# Epoch 1, batch: 167/469, loss: -7269.00
# Epoch 1, batch: 168/469, loss: -7134.70
# Epoch 1, batch: 169/469, loss: -7339.43
# Epoch 1, batch: 170/469, loss: -7355.84
# Epoch 1, batch: 171/469, loss: -7196.22
# Epoch 1, batch: 172/469, loss: -7349.77
# Epoch 1, batch: 173/469, loss: -7097.08
# Epoch 1, batch: 174/469, loss: -7117.11
# Epoch 1, batch: 175/469, loss: -7464.62
# Epoch 1, batch: 176/469, loss: -7396.58
# Epoch 1, batch: 177/469, loss: -7387.35
# Epoch 1, batch: 178/469, loss: -7443.44
# Epoch 1, batch: 179/469, loss: -7329.70
# Epoch 1, batch: 180/469, loss: -7159.83
# Epoch 1, batch: 181/469, loss: -7300.61
# Epoch 1, batch: 182/469, loss: -7396.29
# Epoch 1, batch: 183/469, loss: -7106.47
# Epoch 1, batch: 184/469, loss: -7156.67
# Epoch 1, batch: 185/469, loss: -7569.67
# Epoch 1, batch: 186/469, loss: -7522.75
# Epoch 1, batch: 187/469, loss: -7411.60
# Epoch 1, batch: 188/469, loss: -7083.04
# Epoch 1, batch: 189/469, loss: -7400.22
# Epoch 1, batch: 190/469, loss: -7357.29
# Epoch 1, batch: 191/469, loss: -7354.01
# Epoch 1, batch: 192/469, loss: -7512.56
# Epoch 1, batch: 193/469, loss: -7496.86
# Epoch 1, batch: 194/469, loss: -7261.25
# Epoch 1, batch: 195/469, loss: -7466.93
# Epoch 1, batch: 196/469, loss: -7526.25
# Epoch 1, batch: 197/469, loss: -7212.35
# Epoch 1, batch: 198/469, loss: -7077.40
# Epoch 1, batch: 199/469, loss: -7191.66
# Epoch 1, batch: 200/469, loss: -7506.36
# Epoch 1, batch: 201/469, loss: -7331.94
# Epoch 1, batch: 202/469, loss: -7493.12
# Epoch 1, batch: 203/469, loss: -7578.44
# Epoch 1, batch: 204/469, loss: -7587.13
# Epoch 1, batch: 205/469, loss: -7205.11
# Epoch 1, batch: 206/469, loss: -7415.53
# Epoch 1, batch: 207/469, loss: -7557.30
# Epoch 1, batch: 208/469, loss: -7378.58
# Epoch 1, batch: 209/469, loss: -7324.02
# Epoch 1, batch: 210/469, loss: -7697.76
# Epoch 1, batch: 211/469, loss: -7362.48
# Epoch 1, batch: 212/469, loss: -7320.03
# Epoch 1, batch: 213/469, loss: -7573.08
# Epoch 1, batch: 214/469, loss: -7192.29
# Epoch 1, batch: 215/469, loss: -7394.60
# Epoch 1, batch: 216/469, loss: -7298.15
# Epoch 1, batch: 217/469, loss: -7448.74
# Epoch 1, batch: 218/469, loss: -7343.86
# Epoch 1, batch: 219/469, loss: -7413.97
# Epoch 1, batch: 220/469, loss: -7429.70
# Epoch 1, batch: 221/469, loss: -7461.51
# Epoch 1, batch: 222/469, loss: -7540.28
# Epoch 1, batch: 223/469, loss: -7504.91
# Epoch 1, batch: 224/469, loss: -7161.16
# Epoch 1, batch: 225/469, loss: -7551.10
# Epoch 1, batch: 226/469, loss: -7548.62
# Epoch 1, batch: 227/469, loss: -7244.31
# Epoch 1, batch: 228/469, loss: -7581.12
# Epoch 1, batch: 229/469, loss: -7512.14
# Epoch 1, batch: 230/469, loss: -7869.97
# Epoch 1, batch: 231/469, loss: -7686.16
# Epoch 1, batch: 232/469, loss: -7692.64
# Epoch 1, batch: 233/469, loss: -7476.73
# Epoch 1, batch: 234/469, loss: -7171.78
# Epoch 1, batch: 235/469, loss: -7415.22
# Epoch 1, batch: 236/469, loss: -7505.40
# Epoch 1, batch: 237/469, loss: -7637.10
# Epoch 1, batch: 238/469, loss: -7727.34
# Epoch 1, batch: 239/469, loss: -7779.34
# Epoch 1, batch: 240/469, loss: -7612.00
# Epoch 1, batch: 241/469, loss: -7803.86
# Epoch 1, batch: 242/469, loss: -7555.41
# Epoch 1, batch: 243/469, loss: -7636.25
# Epoch 1, batch: 244/469, loss: -7677.31
# Epoch 1, batch: 245/469, loss: -8001.35
# Epoch 1, batch: 246/469, loss: -7555.36
# Epoch 1, batch: 247/469, loss: -7728.76
# Epoch 1, batch: 248/469, loss: -7833.22
# Epoch 1, batch: 249/469, loss: -7535.21
# Epoch 1, batch: 250/469, loss: -7718.05
# Epoch 1, batch: 251/469, loss: -7510.79
# Epoch 1, batch: 252/469, loss: -7683.23
# Epoch 1, batch: 253/469, loss: -7904.34
# Epoch 1, batch: 254/469, loss: -7573.87
# Epoch 1, batch: 255/469, loss: -7879.24
# Epoch 1, batch: 256/469, loss: -7657.02
# Epoch 1, batch: 257/469, loss: -7890.27
# Epoch 1, batch: 258/469, loss: -7707.47
# Epoch 1, batch: 259/469, loss: -7684.62
# Epoch 1, batch: 260/469, loss: -7789.62
# Epoch 1, batch: 261/469, loss: -7916.66
# Epoch 1, batch: 262/469, loss: -7833.81
# Epoch 1, batch: 263/469, loss: -7879.01
# Epoch 1, batch: 264/469, loss: -7911.41
# Epoch 1, batch: 265/469, loss: -8090.66
# Epoch 1, batch: 266/469, loss: -7686.00
# Epoch 1, batch: 267/469, loss: -7521.57
# Epoch 1, batch: 268/469, loss: -7847.52
# Epoch 1, batch: 269/469, loss: -7828.09
# Epoch 1, batch: 270/469, loss: -7740.89
# Epoch 1, batch: 271/469, loss: -7920.07
# Epoch 1, batch: 272/469, loss: -7797.50
# Epoch 1, batch: 273/469, loss: -7524.77
# Epoch 1, batch: 274/469, loss: -8124.35
# Epoch 1, batch: 275/469, loss: -7857.56
# Epoch 1, batch: 276/469, loss: -7828.20
# Epoch 1, batch: 277/469, loss: -7857.67
# Epoch 1, batch: 278/469, loss: -8194.50
# Epoch 1, batch: 279/469, loss: -7845.41
# Epoch 1, batch: 280/469, loss: -7937.18
# Epoch 1, batch: 281/469, loss: -8073.71
# Epoch 1, batch: 282/469, loss: -8074.39
# Epoch 1, batch: 283/469, loss: -8115.80
# Epoch 1, batch: 284/469, loss: -7895.17
# Epoch 1, batch: 285/469, loss: -7961.71
# Epoch 1, batch: 286/469, loss: -8033.12
# Epoch 1, batch: 287/469, loss: -7703.75
# Epoch 1, batch: 288/469, loss: -8009.92
# Epoch 1, batch: 289/469, loss: -8101.64
# Epoch 1, batch: 290/469, loss: -7673.17
# Epoch 1, batch: 291/469, loss: -7820.29
# Epoch 1, batch: 292/469, loss: -7946.70
# Epoch 1, batch: 293/469, loss: -7760.17
# Epoch 1, batch: 294/469, loss: -7971.37
# Epoch 1, batch: 295/469, loss: -8034.46
# Epoch 1, batch: 296/469, loss: -8007.56
# Epoch 1, batch: 297/469, loss: -7957.58
# Epoch 1, batch: 298/469, loss: -8277.09
# Epoch 1, batch: 299/469, loss: -8077.26
# Epoch 1, batch: 300/469, loss: -7704.29
# Epoch 1, batch: 301/469, loss: -8156.26
# Epoch 1, batch: 302/469, loss: -7900.27
# Epoch 1, batch: 303/469, loss: -7729.78
# Epoch 1, batch: 304/469, loss: -8051.34
# Epoch 1, batch: 305/469, loss: -7996.62
# Epoch 1, batch: 306/469, loss: -7933.91
# Epoch 1, batch: 307/469, loss: -7857.47
# Epoch 1, batch: 308/469, loss: -7862.56
# Epoch 1, batch: 309/469, loss: -7958.46
# Epoch 1, batch: 310/469, loss: -7992.34
# Epoch 1, batch: 311/469, loss: -7715.46
# Epoch 1, batch: 312/469, loss: -7930.58
# Epoch 1, batch: 313/469, loss: -8106.32
# Epoch 1, batch: 314/469, loss: -7663.27
# Epoch 1, batch: 315/469, loss: -7716.65
# Epoch 1, batch: 316/469, loss: -7751.80
# Epoch 1, batch: 317/469, loss: -7962.56
# Epoch 1, batch: 318/469, loss: -7916.45
# Epoch 1, batch: 319/469, loss: -7929.89
# Epoch 1, batch: 320/469, loss: -8105.34
# Epoch 1, batch: 321/469, loss: -7644.91
# Epoch 1, batch: 322/469, loss: -8000.61
# Epoch 1, batch: 323/469, loss: -7904.51
# Epoch 1, batch: 324/469, loss: -7936.60
# Epoch 1, batch: 325/469, loss: -7846.69
# Epoch 1, batch: 326/469, loss: -8279.85
# Epoch 1, batch: 327/469, loss: -8189.06
# Epoch 1, batch: 328/469, loss: -7719.69
# Epoch 1, batch: 329/469, loss: -8083.10
# Epoch 1, batch: 330/469, loss: -8118.25
# Epoch 1, batch: 331/469, loss: -8041.21
# Epoch 1, batch: 332/469, loss: -7904.79
# Epoch 1, batch: 333/469, loss: -8230.90
# Epoch 1, batch: 334/469, loss: -8373.22
# Epoch 1, batch: 335/469, loss: -7867.95
# Epoch 1, batch: 336/469, loss: -7851.13
# Epoch 1, batch: 337/469, loss: -8184.68
# Epoch 1, batch: 338/469, loss: -7900.69
# Epoch 1, batch: 339/469, loss: -7956.79
# Epoch 1, batch: 340/469, loss: -7917.28
# Epoch 1, batch: 341/469, loss: -8103.05
# Epoch 1, batch: 342/469, loss: -8020.00
# Epoch 1, batch: 343/469, loss: -8009.91
# Epoch 1, batch: 344/469, loss: -8284.74
# Epoch 1, batch: 345/469, loss: -8261.15
# Epoch 1, batch: 346/469, loss: -8231.61
# Epoch 1, batch: 347/469, loss: -8095.27
# Epoch 1, batch: 348/469, loss: -8254.67
# Epoch 1, batch: 349/469, loss: -8058.83
# Epoch 1, batch: 350/469, loss: -8034.65
# Epoch 1, batch: 351/469, loss: -8315.99
# Epoch 1, batch: 352/469, loss: -8100.45
# Epoch 1, batch: 353/469, loss: -7962.01
# Epoch 1, batch: 354/469, loss: -8127.15
# Epoch 1, batch: 355/469, loss: -8115.83
# Epoch 1, batch: 356/469, loss: -7986.12
# Epoch 1, batch: 357/469, loss: -8222.74
# Epoch 1, batch: 358/469, loss: -8027.81
# Epoch 1, batch: 359/469, loss: -8191.57
# Epoch 1, batch: 360/469, loss: -7837.97
# Epoch 1, batch: 361/469, loss: -8167.04
# Epoch 1, batch: 362/469, loss: -8184.99
# Epoch 1, batch: 363/469, loss: -8244.42
# Epoch 1, batch: 364/469, loss: -8268.25
# Epoch 1, batch: 365/469, loss: -8122.94
# Epoch 1, batch: 366/469, loss: -8227.35
# Epoch 1, batch: 367/469, loss: -7990.07
# Epoch 1, batch: 368/469, loss: -8096.19
# Epoch 1, batch: 369/469, loss: -8158.54
# Epoch 1, batch: 370/469, loss: -8030.47
# Epoch 1, batch: 371/469, loss: -7981.00
# Epoch 1, batch: 372/469, loss: -8281.35
# Epoch 1, batch: 373/469, loss: -8226.28
# Epoch 1, batch: 374/469, loss: -8171.51
# Epoch 1, batch: 375/469, loss: -8238.31
# Epoch 1, batch: 376/469, loss: -8138.65
# Epoch 1, batch: 377/469, loss: -8203.83
# Epoch 1, batch: 378/469, loss: -7850.50
# Epoch 1, batch: 379/469, loss: -8295.71
# Epoch 1, batch: 380/469, loss: -8345.09
# Epoch 1, batch: 381/469, loss: -8234.36
# Epoch 1, batch: 382/469, loss: -8204.30
# Epoch 1, batch: 383/469, loss: -8284.88
# Epoch 1, batch: 384/469, loss: -8003.46
# Epoch 1, batch: 385/469, loss: -8151.05
# Epoch 1, batch: 386/469, loss: -8243.43
# Epoch 1, batch: 387/469, loss: -8058.72
# Epoch 1, batch: 388/469, loss: -8276.37
# Epoch 1, batch: 389/469, loss: -8066.34
# Epoch 1, batch: 390/469, loss: -8032.31
# Epoch 1, batch: 391/469, loss: -8282.60
# Epoch 1, batch: 392/469, loss: -8298.58
# Epoch 1, batch: 393/469, loss: -8220.40
# Epoch 1, batch: 394/469, loss: -8352.69
# Epoch 1, batch: 395/469, loss: -8307.50
# Epoch 1, batch: 396/469, loss: -8363.27
# Epoch 1, batch: 397/469, loss: -8138.15
# Epoch 1, batch: 398/469, loss: -8077.98
# Epoch 1, batch: 399/469, loss: -8299.96
# Epoch 1, batch: 400/469, loss: -8097.51
# Epoch 1, batch: 401/469, loss: -8398.48
# Epoch 1, batch: 402/469, loss: -7998.21
# Epoch 1, batch: 403/469, loss: -8254.17
# Epoch 1, batch: 404/469, loss: -8031.25
# Epoch 1, batch: 405/469, loss: -8190.50
# Epoch 1, batch: 406/469, loss: -8142.43
# Epoch 1, batch: 407/469, loss: -8376.30
# Epoch 1, batch: 408/469, loss: -8281.07
# Epoch 1, batch: 409/469, loss: -8150.81
# Epoch 1, batch: 410/469, loss: -8129.53
# Epoch 1, batch: 411/469, loss: -7958.26
# Epoch 1, batch: 412/469, loss: -8473.65
# Epoch 1, batch: 413/469, loss: -8209.45
# Epoch 1, batch: 414/469, loss: -8095.86
# Epoch 1, batch: 415/469, loss: -8290.44
# Epoch 1, batch: 416/469, loss: -8027.38
# Epoch 1, batch: 417/469, loss: -8561.78
# Epoch 1, batch: 418/469, loss: -8240.78
# Epoch 1, batch: 419/469, loss: -8144.49
# Epoch 1, batch: 420/469, loss: -8062.77
# Epoch 1, batch: 421/469, loss: -8488.29
# Epoch 1, batch: 422/469, loss: -8112.81
# Epoch 1, batch: 423/469, loss: -8246.20
# Epoch 1, batch: 424/469, loss: -8268.19
# Epoch 1, batch: 425/469, loss: -8220.08
# Epoch 1, batch: 426/469, loss: -7928.28
# Epoch 1, batch: 427/469, loss: -8299.55
# Epoch 1, batch: 428/469, loss: -8476.12
# Epoch 1, batch: 429/469, loss: -8436.97
# Epoch 1, batch: 430/469, loss: -8188.31
# Epoch 1, batch: 431/469, loss: -8165.09
# Epoch 1, batch: 432/469, loss: -8433.07
# Epoch 1, batch: 433/469, loss: -8433.09
# Epoch 1, batch: 434/469, loss: -8538.90
# Epoch 1, batch: 435/469, loss: -8511.55
# Epoch 1, batch: 436/469, loss: -8268.68
# Epoch 1, batch: 437/469, loss: -8209.24
# Epoch 1, batch: 438/469, loss: -8387.89
# Epoch 1, batch: 439/469, loss: -8140.75
# Epoch 1, batch: 440/469, loss: -8169.61
# Epoch 1, batch: 441/469, loss: -8137.68
# Epoch 1, batch: 442/469, loss: -8074.78
# Epoch 1, batch: 443/469, loss: -8226.27
# Epoch 1, batch: 444/469, loss: -8330.13
# Epoch 1, batch: 445/469, loss: -8298.77
# Epoch 1, batch: 446/469, loss: -8253.14
# Epoch 1, batch: 447/469, loss: -8192.01
# Epoch 1, batch: 448/469, loss: -8334.26
# Epoch 1, batch: 449/469, loss: -8123.12
# Epoch 1, batch: 450/469, loss: -8106.90
# Epoch 1, batch: 451/469, loss: -8361.47
# Epoch 1, batch: 452/469, loss: -8171.42
# Epoch 1, batch: 453/469, loss: -8197.15
# Epoch 1, batch: 454/469, loss: -8169.59
# Epoch 1, batch: 455/469, loss: -8194.19
# Epoch 1, batch: 456/469, loss: -8574.50
# Epoch 1, batch: 457/469, loss: -8286.15
# Epoch 1, batch: 458/469, loss: -8498.70
# Epoch 1, batch: 459/469, loss: -8327.41
# Epoch 1, batch: 460/469, loss: -8207.68
# Epoch 1, batch: 461/469, loss: -8559.66
# Epoch 1, batch: 462/469, loss: -8142.96
# Epoch 1, batch: 463/469, loss: -8353.71
# Epoch 1, batch: 464/469, loss: -8260.19
# Epoch 1, batch: 465/469, loss: -7971.34
# Epoch 1, batch: 466/469, loss: -8435.53
# Epoch 1, batch: 467/469, loss: -8302.16
# Epoch 1, batch: 468/469, loss: -8208.10
# Epoch 2, batch: 0/469, loss: -8319.12
# Epoch 2, batch: 1/469, loss: -8447.28
# Epoch 2, batch: 2/469, loss: -7967.86
# Epoch 2, batch: 3/469, loss: -8285.45
# Epoch 2, batch: 4/469, loss: -8169.21
# Epoch 2, batch: 5/469, loss: -8424.54
# Epoch 2, batch: 6/469, loss: -8381.06
# Epoch 2, batch: 7/469, loss: -8074.18
# Epoch 2, batch: 8/469, loss: -8146.09
# Epoch 2, batch: 9/469, loss: -8230.25
# Epoch 2, batch: 10/469, loss: -8366.69
# Epoch 2, batch: 11/469, loss: -8508.21
# Epoch 2, batch: 12/469, loss: -8015.46
# Epoch 2, batch: 13/469, loss: -8330.34
# Epoch 2, batch: 14/469, loss: -8261.64
# Epoch 2, batch: 15/469, loss: -8335.23
# Epoch 2, batch: 16/469, loss: -8677.27
# Epoch 2, batch: 17/469, loss: -8198.63
# Epoch 2, batch: 18/469, loss: -8303.72
# Epoch 2, batch: 19/469, loss: -8337.68
# Epoch 2, batch: 20/469, loss: -8216.58
# Epoch 2, batch: 21/469, loss: -8099.52
# Epoch 2, batch: 22/469, loss: -8481.66
# Epoch 2, batch: 23/469, loss: -8501.12
# Epoch 2, batch: 24/469, loss: -8586.58
# Epoch 2, batch: 25/469, loss: -8531.33
# Epoch 2, batch: 26/469, loss: -8408.17
# Epoch 2, batch: 27/469, loss: -8624.38
# Epoch 2, batch: 28/469, loss: -8482.21
# Epoch 2, batch: 29/469, loss: -8521.13
# Epoch 2, batch: 30/469, loss: -8347.35
# Epoch 2, batch: 31/469, loss: -8200.09
# Epoch 2, batch: 32/469, loss: -8247.24
# Epoch 2, batch: 33/469, loss: -8563.18
# Epoch 2, batch: 34/469, loss: -8287.72
# Epoch 2, batch: 35/469, loss: -8559.90
# Epoch 2, batch: 36/469, loss: -8471.79
# Epoch 2, batch: 37/469, loss: -8466.28
# Epoch 2, batch: 38/469, loss: -8406.42
# Epoch 2, batch: 39/469, loss: -8355.94
# Epoch 2, batch: 40/469, loss: -8505.00
# Epoch 2, batch: 41/469, loss: -8380.65
# Epoch 2, batch: 42/469, loss: -8524.68
# Epoch 2, batch: 43/469, loss: -8409.92
# Epoch 2, batch: 44/469, loss: -8538.03
# Epoch 2, batch: 45/469, loss: -8683.51
# Epoch 2, batch: 46/469, loss: -8446.94
# Epoch 2, batch: 47/469, loss: -8512.55
# Epoch 2, batch: 48/469, loss: -8385.54
# Epoch 2, batch: 49/469, loss: -8360.12
# Epoch 2, batch: 50/469, loss: -8013.15
# Epoch 2, batch: 51/469, loss: -8426.57
# Epoch 2, batch: 52/469, loss: -8561.71
# Epoch 2, batch: 53/469, loss: -8622.80
# Epoch 2, batch: 54/469, loss: -8259.69
# Epoch 2, batch: 55/469, loss: -8406.80
# Epoch 2, batch: 56/469, loss: -8355.24
# Epoch 2, batch: 57/469, loss: -8591.73
# Epoch 2, batch: 58/469, loss: -8465.31
# Epoch 2, batch: 59/469, loss: -8632.15
# Epoch 2, batch: 60/469, loss: -8617.39
# Epoch 2, batch: 61/469, loss: -8487.91
# Epoch 2, batch: 62/469, loss: -8287.75
# Epoch 2, batch: 63/469, loss: -8662.56
# Epoch 2, batch: 64/469, loss: -8360.01
# Epoch 2, batch: 65/469, loss: -8693.16
# Epoch 2, batch: 66/469, loss: -8565.58
# Epoch 2, batch: 67/469, loss: -8527.65
# Epoch 2, batch: 68/469, loss: -8216.80
# Epoch 2, batch: 69/469, loss: -8452.74
# Epoch 2, batch: 70/469, loss: -8578.97
# Epoch 2, batch: 71/469, loss: -8213.43
# Epoch 2, batch: 72/469, loss: -8379.99
# Epoch 2, batch: 73/469, loss: -8341.04
# Epoch 2, batch: 74/469, loss: -8482.61
# Epoch 2, batch: 75/469, loss: -8536.88
# Epoch 2, batch: 76/469, loss: -8806.87
# Epoch 2, batch: 77/469, loss: -8820.78
# Epoch 2, batch: 78/469, loss: -8569.62
# Epoch 2, batch: 79/469, loss: -8391.37
# Epoch 2, batch: 80/469, loss: -8501.06
# Epoch 2, batch: 81/469, loss: -8251.48
# Epoch 2, batch: 82/469, loss: -8619.65
# Epoch 2, batch: 83/469, loss: -8441.34
# Epoch 2, batch: 84/469, loss: -8229.72
# Epoch 2, batch: 85/469, loss: -8433.84
# Epoch 2, batch: 86/469, loss: -8621.51
# Epoch 2, batch: 87/469, loss: -8486.63
# Epoch 2, batch: 88/469, loss: -8606.24
# Epoch 2, batch: 89/469, loss: -8633.82
# Epoch 2, batch: 90/469, loss: -8789.92
# Epoch 2, batch: 91/469, loss: -8246.86
# Epoch 2, batch: 92/469, loss: -8573.35
# Epoch 2, batch: 93/469, loss: -8625.60
# Epoch 2, batch: 94/469, loss: -8728.88
# Epoch 2, batch: 95/469, loss: -8569.47
# Epoch 2, batch: 96/469, loss: -8693.53
# Epoch 2, batch: 97/469, loss: -8653.81
# Epoch 2, batch: 98/469, loss: -8579.75
# Epoch 2, batch: 99/469, loss: -8633.79
# Epoch 2, batch: 100/469, loss: -8714.50
# Epoch 2, batch: 101/469, loss: -8465.68
# Epoch 2, batch: 102/469, loss: -8595.66
# Epoch 2, batch: 103/469, loss: -9016.40
# Epoch 2, batch: 104/469, loss: -8755.65
# Epoch 2, batch: 105/469, loss: -8321.28
# Epoch 2, batch: 106/469, loss: -8928.74
# Epoch 2, batch: 107/469, loss: -8680.01
# Epoch 2, batch: 108/469, loss: -8460.55
# Epoch 2, batch: 109/469, loss: -8680.11
# Epoch 2, batch: 110/469, loss: -8609.02
# Epoch 2, batch: 111/469, loss: -8512.94
# Epoch 2, batch: 112/469, loss: -8644.77
# Epoch 2, batch: 113/469, loss: -8513.07
# Epoch 2, batch: 114/469, loss: -8461.33
# Epoch 2, batch: 115/469, loss: -8482.87
# Epoch 2, batch: 116/469, loss: -8797.06
# Epoch 2, batch: 117/469, loss: -8620.97
# Epoch 2, batch: 118/469, loss: -8635.96
# Epoch 2, batch: 119/469, loss: -8750.39
# Epoch 2, batch: 120/469, loss: -8851.44
# Epoch 2, batch: 121/469, loss: -8961.29
# Epoch 2, batch: 122/469, loss: -8659.20
# Epoch 2, batch: 123/469, loss: -8570.68
# Epoch 2, batch: 124/469, loss: -8665.32
# Epoch 2, batch: 125/469, loss: -8758.00
# Epoch 2, batch: 126/469, loss: -8755.57
# Epoch 2, batch: 127/469, loss: -8770.57
# Epoch 2, batch: 128/469, loss: -8388.18
# Epoch 2, batch: 129/469, loss: -8612.90
# Epoch 2, batch: 130/469, loss: -8729.50
# Epoch 2, batch: 131/469, loss: -9108.00
# Epoch 2, batch: 132/469, loss: -8826.75
# Epoch 2, batch: 133/469, loss: -8776.90
# Epoch 2, batch: 134/469, loss: -8694.19
# Epoch 2, batch: 135/469, loss: -8830.00
# Epoch 2, batch: 136/469, loss: -8479.37
# Epoch 2, batch: 137/469, loss: -8621.63
# Epoch 2, batch: 138/469, loss: -8995.47
# Epoch 2, batch: 139/469, loss: -8836.20
# Epoch 2, batch: 140/469, loss: -8276.42
# Epoch 2, batch: 141/469, loss: -8614.11
# Epoch 2, batch: 142/469, loss: -8592.21
# Epoch 2, batch: 143/469, loss: -8684.17
# Epoch 2, batch: 144/469, loss: -8880.60
# Epoch 2, batch: 145/469, loss: -8593.88
# Epoch 2, batch: 146/469, loss: -8670.01
# Epoch 2, batch: 147/469, loss: -9029.00
# Epoch 2, batch: 148/469, loss: -8769.06
# Epoch 2, batch: 149/469, loss: -8957.82
# Epoch 2, batch: 150/469, loss: -8666.56
# Epoch 2, batch: 151/469, loss: -8741.02
# Epoch 2, batch: 152/469, loss: -8538.42
# Epoch 2, batch: 153/469, loss: -8721.57
# Epoch 2, batch: 154/469, loss: -8805.00
# Epoch 2, batch: 155/469, loss: -8593.65
# Epoch 2, batch: 156/469, loss: -8723.98
# Epoch 2, batch: 157/469, loss: -8750.04
# Epoch 2, batch: 158/469, loss: -8774.18
# Epoch 2, batch: 159/469, loss: -8832.54
# Epoch 2, batch: 160/469, loss: -8694.00
# Epoch 2, batch: 161/469, loss: -8472.67
# Epoch 2, batch: 162/469, loss: -8722.85
# Epoch 2, batch: 163/469, loss: -8861.71
# Epoch 2, batch: 164/469, loss: -8740.01
# Epoch 2, batch: 165/469, loss: -8894.08
# Epoch 2, batch: 166/469, loss: -8940.47
# Epoch 2, batch: 167/469, loss: -8936.99
# Epoch 2, batch: 168/469, loss: -8577.54
# Epoch 2, batch: 169/469, loss: -8741.89
# Epoch 2, batch: 170/469, loss: -8860.18
# Epoch 2, batch: 171/469, loss: -8846.10
# Epoch 2, batch: 172/469, loss: -8942.61
# Epoch 2, batch: 173/469, loss: -8937.56
# Epoch 2, batch: 174/469, loss: -8850.62
# Epoch 2, batch: 175/469, loss: -8691.26
# Epoch 2, batch: 176/469, loss: -8797.26
# Epoch 2, batch: 177/469, loss: -8792.03
# Epoch 2, batch: 178/469, loss: -8799.47
# Epoch 2, batch: 179/469, loss: -8818.01
# Epoch 2, batch: 180/469, loss: -8853.92
# Epoch 2, batch: 181/469, loss: -8565.48
# Epoch 2, batch: 182/469, loss: -9039.62
# Epoch 2, batch: 183/469, loss: -8723.00
# Epoch 2, batch: 184/469, loss: -9029.43
# Epoch 2, batch: 185/469, loss: -8897.39
# Epoch 2, batch: 186/469, loss: -8780.75
# Epoch 2, batch: 187/469, loss: -8666.29
# Epoch 2, batch: 188/469, loss: -8711.23
# Epoch 2, batch: 189/469, loss: -8792.92
# Epoch 2, batch: 190/469, loss: -8728.86
# Epoch 2, batch: 191/469, loss: -8758.76
# Epoch 2, batch: 192/469, loss: -8883.43
# Epoch 2, batch: 193/469, loss: -8669.63
# Epoch 2, batch: 194/469, loss: -8604.89
# Epoch 2, batch: 195/469, loss: -8870.35
# Epoch 2, batch: 196/469, loss: -8882.93
# Epoch 2, batch: 197/469, loss: -8805.08
# Epoch 2, batch: 198/469, loss: -8796.42
# Epoch 2, batch: 199/469, loss: -8794.30
# Epoch 2, batch: 200/469, loss: -8822.98
# Epoch 2, batch: 201/469, loss: -8795.86
# Epoch 2, batch: 202/469, loss: -8775.04
# Epoch 2, batch: 203/469, loss: -8857.42
# Epoch 2, batch: 204/469, loss: -8637.52
# Epoch 2, batch: 205/469, loss: -8863.80
# Epoch 2, batch: 206/469, loss: -8818.28
# Epoch 2, batch: 207/469, loss: -8764.93
# Epoch 2, batch: 208/469, loss: -8837.31
# Epoch 2, batch: 209/469, loss: -8968.78
# Epoch 2, batch: 210/469, loss: -9063.77
# Epoch 2, batch: 211/469, loss: -8889.97
# Epoch 2, batch: 212/469, loss: -8789.78
# Epoch 2, batch: 213/469, loss: -9112.92
# Epoch 2, batch: 214/469, loss: -8725.82
# Epoch 2, batch: 215/469, loss: -9164.05
# Epoch 2, batch: 216/469, loss: -8867.88
# Epoch 2, batch: 217/469, loss: -9109.64
# Epoch 2, batch: 218/469, loss: -8930.38
# Epoch 2, batch: 219/469, loss: -9057.44
# Epoch 2, batch: 220/469, loss: -8669.18
# Epoch 2, batch: 221/469, loss: -8898.98
# Epoch 2, batch: 222/469, loss: -8654.93
# Epoch 2, batch: 223/469, loss: -8835.65
# Epoch 2, batch: 224/469, loss: -8912.54
# Epoch 2, batch: 225/469, loss: -8950.88
# Epoch 2, batch: 226/469, loss: -8976.85
# Epoch 2, batch: 227/469, loss: -9175.01
# Epoch 2, batch: 228/469, loss: -9008.32
# Epoch 2, batch: 229/469, loss: -9057.94
# Epoch 2, batch: 230/469, loss: -8869.17
# Epoch 2, batch: 231/469, loss: -8816.16
# Epoch 2, batch: 232/469, loss: -8980.10
# Epoch 2, batch: 233/469, loss: -8885.46
# Epoch 2, batch: 234/469, loss: -8878.99
# Epoch 2, batch: 235/469, loss: -8897.30
# Epoch 2, batch: 236/469, loss: -8939.62
# Epoch 2, batch: 237/469, loss: -8857.26
# Epoch 2, batch: 238/469, loss: -8887.55
# Epoch 2, batch: 239/469, loss: -8802.08
# Epoch 2, batch: 240/469, loss: -8959.97
# Epoch 2, batch: 241/469, loss: -8763.27
# Epoch 2, batch: 242/469, loss: -8861.46
# Epoch 2, batch: 243/469, loss: -8615.55
# Epoch 2, batch: 244/469, loss: -8900.54
# Epoch 2, batch: 245/469, loss: -8623.26
# Epoch 2, batch: 246/469, loss: -8756.45
# Epoch 2, batch: 247/469, loss: -9026.32
# Epoch 2, batch: 248/469, loss: -8846.20
# Epoch 2, batch: 249/469, loss: -8878.08
# Epoch 2, batch: 250/469, loss: -8909.77
# Epoch 2, batch: 251/469, loss: -8762.90
# Epoch 2, batch: 252/469, loss: -9211.88
# Epoch 2, batch: 253/469, loss: -9152.28
# Epoch 2, batch: 254/469, loss: -8789.37
# Epoch 2, batch: 255/469, loss: -8786.29
# Epoch 2, batch: 256/469, loss: -8997.20
# Epoch 2, batch: 257/469, loss: -8546.21
# Epoch 2, batch: 258/469, loss: -9014.91
# Epoch 2, batch: 259/469, loss: -8967.53
# Epoch 2, batch: 260/469, loss: -8869.56
# Epoch 2, batch: 261/469, loss: -8875.17
# Epoch 2, batch: 262/469, loss: -8997.99
# Epoch 2, batch: 263/469, loss: -8897.85
# Epoch 2, batch: 264/469, loss: -8819.62
# ...
# Epoch 19, batch: 88/469, loss: -11157.77
# Epoch 19, batch: 89/469, loss: -11027.14
# Epoch 19, batch: 90/469, loss: -11326.10
# Epoch 19, batch: 91/469, loss: -11229.93
# Epoch 19, batch: 92/469, loss: -11057.17
# Epoch 19, batch: 93/469, loss: -11044.04
# Epoch 19, batch: 94/469, loss: -11222.38
# Epoch 19, batch: 95/469, loss: -11113.09
# Epoch 19, batch: 96/469, loss: -11071.85
# Epoch 19, batch: 97/469, loss: -11275.71
# Epoch 19, batch: 98/469, loss: -11305.76
# Epoch 19, batch: 99/469, loss: -11271.46
# Epoch 19, batch: 100/469, loss: -11177.33
# Epoch 19, batch: 101/469, loss: -11266.82
# Epoch 19, batch: 102/469, loss: -11068.99
# Epoch 19, batch: 103/469, loss: -11291.52
# Epoch 19, batch: 104/469, loss: -11226.04
# Epoch 19, batch: 105/469, loss: -11207.17
# Epoch 19, batch: 106/469, loss: -11107.25
# Epoch 19, batch: 107/469, loss: -11047.51
# Epoch 19, batch: 108/469, loss: -11110.66
# Epoch 19, batch: 109/469, loss: -11161.33
# Epoch 19, batch: 110/469, loss: -11054.73
# Epoch 19, batch: 111/469, loss: -11133.50
# Epoch 19, batch: 112/469, loss: -11267.99
# Epoch 19, batch: 113/469, loss: -11148.25
# Epoch 19, batch: 114/469, loss: -11287.14
# Epoch 19, batch: 115/469, loss: -11489.95
# Epoch 19, batch: 116/469, loss: -11130.99
# Epoch 19, batch: 117/469, loss: -11198.60
# Epoch 19, batch: 118/469, loss: -11237.31
# Epoch 19, batch: 119/469, loss: -11347.64
# Epoch 19, batch: 120/469, loss: -11305.66
# Epoch 19, batch: 121/469, loss: -11261.01
# Epoch 19, batch: 122/469, loss: -11316.84
# Epoch 19, batch: 123/469, loss: -11278.90
# Epoch 19, batch: 124/469, loss: -11063.40
# Epoch 19, batch: 125/469, loss: -11158.17
# Epoch 19, batch: 126/469, loss: -11103.46
# Epoch 19, batch: 127/469, loss: -11306.94
# Epoch 19, batch: 128/469, loss: -11231.15
# Epoch 19, batch: 129/469, loss: -11148.40
# Epoch 19, batch: 130/469, loss: -11085.67
# Epoch 19, batch: 131/469, loss: -11182.73
# Epoch 19, batch: 132/469, loss: -11238.74
# Epoch 19, batch: 133/469, loss: -11113.37
# Epoch 19, batch: 134/469, loss: -11071.29
# Epoch 19, batch: 135/469, loss: -11185.47
# Epoch 19, batch: 136/469, loss: -11234.55
# Epoch 19, batch: 137/469, loss: -11145.43
# Epoch 19, batch: 138/469, loss: -11234.13
# Epoch 19, batch: 139/469, loss: -11319.21
# Epoch 19, batch: 140/469, loss: -11256.73
# Epoch 19, batch: 141/469, loss: -11123.91
# Epoch 19, batch: 142/469, loss: -11226.43
# Epoch 19, batch: 143/469, loss: -11251.22
# Epoch 19, batch: 144/469, loss: -11315.27
# Epoch 19, batch: 145/469, loss: -11270.84
# Epoch 19, batch: 146/469, loss: -11089.41
# Epoch 19, batch: 147/469, loss: -11260.74
# Epoch 19, batch: 148/469, loss: -11265.46
# Epoch 19, batch: 149/469, loss: -11095.24
# Epoch 19, batch: 150/469, loss: -11171.00
# Epoch 19, batch: 151/469, loss: -11081.24
# Epoch 19, batch: 152/469, loss: -11240.24
# Epoch 19, batch: 153/469, loss: -11374.77
# Epoch 19, batch: 154/469, loss: -11262.91
# Epoch 19, batch: 155/469, loss: -11179.54
# Epoch 19, batch: 156/469, loss: -11165.52
# Epoch 19, batch: 157/469, loss: -11201.00
# Epoch 19, batch: 158/469, loss: -11155.14
# Epoch 19, batch: 159/469, loss: -11088.05
# Epoch 19, batch: 160/469, loss: -11272.66
# Epoch 19, batch: 161/469, loss: -11134.58
# Epoch 19, batch: 162/469, loss: -11217.90
# Epoch 19, batch: 163/469, loss: -10894.86
# Epoch 19, batch: 164/469, loss: -11206.76
# Epoch 19, batch: 165/469, loss: -11114.20
# Epoch 19, batch: 166/469, loss: -11300.41
# Epoch 19, batch: 167/469, loss: -11212.01
# Epoch 19, batch: 168/469, loss: -11208.19
# Epoch 19, batch: 169/469, loss: -11112.19
# Epoch 19, batch: 170/469, loss: -11149.24
# Epoch 19, batch: 171/469, loss: -11083.29
# Epoch 19, batch: 172/469, loss: -11293.73
# Epoch 19, batch: 173/469, loss: -11340.82
# Epoch 19, batch: 174/469, loss: -11293.43
# Epoch 19, batch: 175/469, loss: -11121.96
# Epoch 19, batch: 176/469, loss: -11262.65
# Epoch 19, batch: 177/469, loss: -11474.57
# Epoch 19, batch: 178/469, loss: -11311.23
# Epoch 19, batch: 179/469, loss: -11337.81
# Epoch 19, batch: 180/469, loss: -11254.24
# Epoch 19, batch: 181/469, loss: -11129.69
# Epoch 19, batch: 182/469, loss: -11327.29
# Epoch 19, batch: 183/469, loss: -11219.18
# Epoch 19, batch: 184/469, loss: -11105.30
# Epoch 19, batch: 185/469, loss: -11127.43
# Epoch 19, batch: 186/469, loss: -11066.71
# Epoch 19, batch: 187/469, loss: -10997.82
# Epoch 19, batch: 188/469, loss: -11303.33
# Epoch 19, batch: 189/469, loss: -11190.42
# Epoch 19, batch: 190/469, loss: -11187.07
# Epoch 19, batch: 191/469, loss: -11084.38
# Epoch 19, batch: 192/469, loss: -11183.17
# Epoch 19, batch: 193/469, loss: -10983.98
# Epoch 19, batch: 194/469, loss: -11367.06
# Epoch 19, batch: 195/469, loss: -11249.51
# Epoch 19, batch: 196/469, loss: -11200.50
# Epoch 19, batch: 197/469, loss: -11168.83
# Epoch 19, batch: 198/469, loss: -11197.14
# Epoch 19, batch: 199/469, loss: -11253.28
# Epoch 19, batch: 200/469, loss: -11098.11
# Epoch 19, batch: 201/469, loss: -11126.38
# Epoch 19, batch: 202/469, loss: -11222.05
# Epoch 19, batch: 203/469, loss: -11223.55
# Epoch 19, batch: 204/469, loss: -11504.88
# Epoch 19, batch: 205/469, loss: -11383.54
# Epoch 19, batch: 206/469, loss: -11318.96
# Epoch 19, batch: 207/469, loss: -11165.11
# Epoch 19, batch: 208/469, loss: -11080.74
# Epoch 19, batch: 209/469, loss: -11213.07
# Epoch 19, batch: 210/469, loss: -11111.05
# Epoch 19, batch: 211/469, loss: -11271.62
# Epoch 19, batch: 212/469, loss: -11257.54
# Epoch 19, batch: 213/469, loss: -11203.81
# Epoch 19, batch: 214/469, loss: -10978.69
# Epoch 19, batch: 215/469, loss: -11211.68
# Epoch 19, batch: 216/469, loss: -11488.58
# Epoch 19, batch: 217/469, loss: -11094.62
# Epoch 19, batch: 218/469, loss: -11201.53
# Epoch 19, batch: 219/469, loss: -11263.44
# Epoch 19, batch: 220/469, loss: -11353.76
# Epoch 19, batch: 221/469, loss: -11141.10
# Epoch 19, batch: 222/469, loss: -11144.21
# Epoch 19, batch: 223/469, loss: -11130.27
# Epoch 19, batch: 224/469, loss: -11131.02
# Epoch 19, batch: 225/469, loss: -11331.78
# Epoch 19, batch: 226/469, loss: -11229.30
# Epoch 19, batch: 227/469, loss: -10997.50
# Epoch 19, batch: 228/469, loss: -11151.05
# Epoch 19, batch: 229/469, loss: -11042.54
# Epoch 19, batch: 230/469, loss: -11264.75
# Epoch 19, batch: 231/469, loss: -11233.74
# Epoch 19, batch: 232/469, loss: -11250.08
# Epoch 19, batch: 233/469, loss: -11238.33
# Epoch 19, batch: 234/469, loss: -11206.08
# Epoch 19, batch: 235/469, loss: -11298.15
# Epoch 19, batch: 236/469, loss: -11094.68
# Epoch 19, batch: 237/469, loss: -11216.32
# Epoch 19, batch: 238/469, loss: -11055.04
# Epoch 19, batch: 239/469, loss: -11097.62
# Epoch 19, batch: 240/469, loss: -11073.15
# Epoch 19, batch: 241/469, loss: -11214.25
# Epoch 19, batch: 242/469, loss: -10998.74
# Epoch 19, batch: 243/469, loss: -11064.19
# Epoch 19, batch: 244/469, loss: -11220.68
# Epoch 19, batch: 245/469, loss: -11069.13
# Epoch 19, batch: 246/469, loss: -11262.64
# Epoch 19, batch: 247/469, loss: -11391.63
# Epoch 19, batch: 248/469, loss: -11055.66
# Epoch 19, batch: 249/469, loss: -11267.48
# Epoch 19, batch: 250/469, loss: -11161.36
# Epoch 19, batch: 251/469, loss: -11209.32
# Epoch 19, batch: 252/469, loss: -11311.41
# Epoch 19, batch: 253/469, loss: -11168.81
# Epoch 19, batch: 254/469, loss: -11235.84
# Epoch 19, batch: 255/469, loss: -11376.37
# Epoch 19, batch: 256/469, loss: -11168.21
# Epoch 19, batch: 257/469, loss: -11127.28
# Epoch 19, batch: 258/469, loss: -11149.23
# Epoch 19, batch: 259/469, loss: -11214.53
# Epoch 19, batch: 260/469, loss: -11222.41
# Epoch 19, batch: 261/469, loss: -10925.91
# Epoch 19, batch: 262/469, loss: -11173.78
# Epoch 19, batch: 263/469, loss: -11247.07
# Epoch 19, batch: 264/469, loss: -11059.71
# Epoch 19, batch: 265/469, loss: -11147.85
# Epoch 19, batch: 266/469, loss: -11061.49
# Epoch 19, batch: 267/469, loss: -11073.90
# Epoch 19, batch: 268/469, loss: -11138.15
# Epoch 19, batch: 269/469, loss: -11020.02
# Epoch 19, batch: 270/469, loss: -11026.13
# Epoch 19, batch: 271/469, loss: -11141.80
# Epoch 19, batch: 272/469, loss: -11452.61
# Epoch 19, batch: 273/469, loss: -11248.97
# Epoch 19, batch: 274/469, loss: -11180.33
# Epoch 19, batch: 275/469, loss: -11134.19
# Epoch 19, batch: 276/469, loss: -11112.71
# Epoch 19, batch: 277/469, loss: -11197.24
# Epoch 19, batch: 278/469, loss: -11271.75
# Epoch 19, batch: 279/469, loss: -11295.05
# Epoch 19, batch: 280/469, loss: -11349.17
# Epoch 19, batch: 281/469, loss: -11179.74
# Epoch 19, batch: 282/469, loss: -11230.10
# Epoch 19, batch: 283/469, loss: -11076.62
# Epoch 19, batch: 284/469, loss: -11256.77
# Epoch 19, batch: 285/469, loss: -11243.61
# Epoch 19, batch: 286/469, loss: -11280.04
# Epoch 19, batch: 287/469, loss: -11152.67
# Epoch 19, batch: 288/469, loss: -11442.23
# Epoch 19, batch: 289/469, loss: -11211.97
# Epoch 19, batch: 290/469, loss: -11119.81
# Epoch 19, batch: 291/469, loss: -11293.46
# Epoch 19, batch: 292/469, loss: -11084.02
# Epoch 19, batch: 293/469, loss: -11082.79
# Epoch 19, batch: 294/469, loss: -11344.81
# Epoch 19, batch: 295/469, loss: -11115.24
# Epoch 19, batch: 296/469, loss: -11307.52
# Epoch 19, batch: 297/469, loss: -11366.50
# Epoch 19, batch: 298/469, loss: -11322.61
# Epoch 19, batch: 299/469, loss: -11145.71
# Epoch 19, batch: 300/469, loss: -11286.59
# Epoch 19, batch: 301/469, loss: -11213.63
# Epoch 19, batch: 302/469, loss: -10953.62
# Epoch 19, batch: 303/469, loss: -11233.72
# Epoch 19, batch: 304/469, loss: -11438.54
# Epoch 19, batch: 305/469, loss: -11203.34
# Epoch 19, batch: 306/469, loss: -10972.03
# Epoch 19, batch: 307/469, loss: -11347.41
# Epoch 19, batch: 308/469, loss: -11272.08
# Epoch 19, batch: 309/469, loss: -11295.61
# Epoch 19, batch: 310/469, loss: -11203.29
# Epoch 19, batch: 311/469, loss: -11143.75
# Epoch 19, batch: 312/469, loss: -11162.74
# Epoch 19, batch: 313/469, loss: -11070.88
# Epoch 19, batch: 314/469, loss: -11368.35
# Epoch 19, batch: 315/469, loss: -11135.37
# Epoch 19, batch: 316/469, loss: -11189.35
# Epoch 19, batch: 317/469, loss: -11243.99
# Epoch 19, batch: 318/469, loss: -11148.19
# Epoch 19, batch: 319/469, loss: -11015.47
# Epoch 19, batch: 320/469, loss: -11326.45
# Epoch 19, batch: 321/469, loss: -11130.57
# Epoch 19, batch: 322/469, loss: -11125.58
# Epoch 19, batch: 323/469, loss: -11184.78
# Epoch 19, batch: 324/469, loss: -11103.58
# Epoch 19, batch: 325/469, loss: -11371.76
# Epoch 19, batch: 326/469, loss: -11047.16
# Epoch 19, batch: 327/469, loss: -11073.09
# Epoch 19, batch: 328/469, loss: -11221.57
# Epoch 19, batch: 329/469, loss: -11415.29
# Epoch 19, batch: 330/469, loss: -11342.01
# Epoch 19, batch: 331/469, loss: -11264.47
# Epoch 19, batch: 332/469, loss: -11165.92
# Epoch 19, batch: 333/469, loss: -11201.97
# Epoch 19, batch: 334/469, loss: -11183.71
# Epoch 19, batch: 335/469, loss: -11094.88
# Epoch 19, batch: 336/469, loss: -11308.54
# Epoch 19, batch: 337/469, loss: -11293.67
# Epoch 19, batch: 338/469, loss: -11256.80
# Epoch 19, batch: 339/469, loss: -11274.92
# Epoch 19, batch: 340/469, loss: -11190.27
# Epoch 19, batch: 341/469, loss: -11287.36
# Epoch 19, batch: 342/469, loss: -11213.63
# Epoch 19, batch: 343/469, loss: -11050.26
# Epoch 19, batch: 344/469, loss: -11288.00
# Epoch 19, batch: 345/469, loss: -11265.34
# Epoch 19, batch: 346/469, loss: -11032.55
# Epoch 19, batch: 347/469, loss: -11221.25
# Epoch 19, batch: 348/469, loss: -11194.58
# Epoch 19, batch: 349/469, loss: -11341.52
# Epoch 19, batch: 350/469, loss: -11135.75
# Epoch 19, batch: 351/469, loss: -11062.96
# Epoch 19, batch: 352/469, loss: -11149.30
# Epoch 19, batch: 353/469, loss: -11006.67
# Epoch 19, batch: 354/469, loss: -11365.03
# Epoch 19, batch: 355/469, loss: -11309.07
# Epoch 19, batch: 356/469, loss: -11205.09
# Epoch 19, batch: 357/469, loss: -11366.10
# Epoch 19, batch: 358/469, loss: -11347.19
# Epoch 19, batch: 359/469, loss: -11398.50
# Epoch 19, batch: 360/469, loss: -11108.05
# Epoch 19, batch: 361/469, loss: -11108.26
# Epoch 19, batch: 362/469, loss: -11111.39
# Epoch 19, batch: 363/469, loss: -11110.48
# Epoch 19, batch: 364/469, loss: -11038.91
# Epoch 19, batch: 365/469, loss: -11348.86
# Epoch 19, batch: 366/469, loss: -11019.21
# Epoch 19, batch: 367/469, loss: -11427.09
# Epoch 19, batch: 368/469, loss: -11182.54
# Epoch 19, batch: 369/469, loss: -11025.01
# Epoch 19, batch: 370/469, loss: -11091.42
# Epoch 19, batch: 371/469, loss: -11217.48
# Epoch 19, batch: 372/469, loss: -11101.80
# Epoch 19, batch: 373/469, loss: -11267.94
# Epoch 19, batch: 374/469, loss: -10975.84
# Epoch 19, batch: 375/469, loss: -11243.26
# Epoch 19, batch: 376/469, loss: -11352.42
# Epoch 19, batch: 377/469, loss: -11297.52
# Epoch 19, batch: 378/469, loss: -11300.90
# Epoch 19, batch: 379/469, loss: -11337.01
# Epoch 19, batch: 380/469, loss: -11047.55
# Epoch 19, batch: 381/469, loss: -11361.64
# Epoch 19, batch: 382/469, loss: -11278.06
# Epoch 19, batch: 383/469, loss: -11190.66
# Epoch 19, batch: 384/469, loss: -11165.39
# Epoch 19, batch: 385/469, loss: -11195.92
# Epoch 19, batch: 386/469, loss: -11205.68
# Epoch 19, batch: 387/469, loss: -11233.04
# Epoch 19, batch: 388/469, loss: -11225.19
# Epoch 19, batch: 389/469, loss: -11068.05
# Epoch 19, batch: 390/469, loss: -11176.20
# Epoch 19, batch: 391/469, loss: -11352.58
# Epoch 19, batch: 392/469, loss: -11024.84
# Epoch 19, batch: 393/469, loss: -11105.61
# Epoch 19, batch: 394/469, loss: -11056.35
# Epoch 19, batch: 395/469, loss: -11287.68
# Epoch 19, batch: 396/469, loss: -11238.38
# Epoch 19, batch: 397/469, loss: -11251.99
# Epoch 19, batch: 398/469, loss: -11193.61
# Epoch 19, batch: 399/469, loss: -11232.08
# Epoch 19, batch: 400/469, loss: -11225.45
# Epoch 19, batch: 401/469, loss: -11148.81
# Epoch 19, batch: 402/469, loss: -11121.54
# Epoch 19, batch: 403/469, loss: -11122.67
# Epoch 19, batch: 404/469, loss: -11151.37
# Epoch 19, batch: 405/469, loss: -11172.97
# Epoch 19, batch: 406/469, loss: -11168.06
# Epoch 19, batch: 407/469, loss: -11311.97
# Epoch 19, batch: 408/469, loss: -11184.39
# Epoch 19, batch: 409/469, loss: -11139.00
# Epoch 19, batch: 410/469, loss: -11179.07
# Epoch 19, batch: 411/469, loss: -11283.42
# Epoch 19, batch: 412/469, loss: -11253.41
# Epoch 19, batch: 413/469, loss: -11056.66
# Epoch 19, batch: 414/469, loss: -11335.88
# Epoch 19, batch: 415/469, loss: -11345.75
# Epoch 19, batch: 416/469, loss: -11074.57
# Epoch 19, batch: 417/469, loss: -11423.62
# Epoch 19, batch: 418/469, loss: -11189.12
# Epoch 19, batch: 419/469, loss: -10970.37
# Epoch 19, batch: 420/469, loss: -11104.99
# Epoch 19, batch: 421/469, loss: -11161.71
# Epoch 19, batch: 422/469, loss: -11143.53
# Epoch 19, batch: 423/469, loss: -11093.87
# Epoch 19, batch: 424/469, loss: -11105.22
# Epoch 19, batch: 425/469, loss: -11100.73
# Epoch 19, batch: 426/469, loss: -11234.78
# Epoch 19, batch: 427/469, loss: -11095.06
# Epoch 19, batch: 428/469, loss: -11157.52
# Epoch 19, batch: 429/469, loss: -11272.75
# Epoch 19, batch: 430/469, loss: -11033.55
# Epoch 19, batch: 431/469, loss: -11178.16
# Epoch 19, batch: 432/469, loss: -11140.56
# Epoch 19, batch: 433/469, loss: -11241.59
# Epoch 19, batch: 434/469, loss: -11083.21
# Epoch 19, batch: 435/469, loss: -11299.96
# Epoch 19, batch: 436/469, loss: -11365.38
# Epoch 19, batch: 437/469, loss: -11149.08
# Epoch 19, batch: 438/469, loss: -11059.20
# Epoch 19, batch: 439/469, loss: -11098.25
# Epoch 19, batch: 440/469, loss: -11109.39
# Epoch 19, batch: 441/469, loss: -11125.21
# Epoch 19, batch: 442/469, loss: -11233.96
# Epoch 19, batch: 443/469, loss: -11128.59
# Epoch 19, batch: 444/469, loss: -11328.66
# Epoch 19, batch: 445/469, loss: -10999.63
# Epoch 19, batch: 446/469, loss: -11130.07
# Epoch 19, batch: 447/469, loss: -10999.48
# Epoch 19, batch: 448/469, loss: -11249.67
# Epoch 19, batch: 449/469, loss: -11366.51
# Epoch 19, batch: 450/469, loss: -11296.42
# Epoch 19, batch: 451/469, loss: -11328.05
# Epoch 19, batch: 452/469, loss: -11383.48
# Epoch 19, batch: 453/469, loss: -11277.55
# Epoch 19, batch: 454/469, loss: -11260.88
# Epoch 19, batch: 455/469, loss: -11252.66
# Epoch 19, batch: 456/469, loss: -11306.41
# Epoch 19, batch: 457/469, loss: -11117.61
# Epoch 19, batch: 458/469, loss: -11219.78
# Epoch 19, batch: 459/469, loss: -11408.02
# Epoch 19, batch: 460/469, loss: -11317.25
# Epoch 19, batch: 461/469, loss: -11206.80
# Epoch 19, batch: 462/469, loss: -11025.63
# Epoch 19, batch: 463/469, loss: -11349.69
# Epoch 19, batch: 464/469, loss: -11130.55
# Epoch 19, batch: 465/469, loss: -11300.28
# Epoch 19, batch: 466/469, loss: -11148.59
# Epoch 19, batch: 467/469, loss: -11200.71
# Epoch 19, batch: 468/469, loss: -11035.03

# %%
classifier = Classifier(nb_latents)
if is_cuda:
  classifier = classifier.to(device)
print(classifier)
# Out:
# Classifier(
#   (fc1): Linear(in_features=20, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
learning_rate = 0.001
momemtum = 0.9
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)
scheduler = lr_scheduler.StepLR(optimizer,step_size = 7,gamma = 0.1)

# %%
vae_parameters = list(model.named_parameters())
for name, param in vae_parameters:
  param.requires_grad = False

# %%
def train_classifier_epoch(epoch):
  classifier.train()
  metric = AccumulatedAccuracyMetric()
  losses = RunningAverage()
  for idx, (data, labels) in enumerate(train_loader):
    data= data.to(device)
    labels = labels.to(device)
    
    
    recon_batch, mu, logvar = model(data)
    ## classifier, pass latent vector
    outputs = classifier(mu)
    classifier_loss = criterion(outputs, labels)
    
    optimizer.zero_grad()
    classifier_loss.backward()
    optimizer.step()
    
    classifier_loss /= data.size(0)
    losses.update(classifier_loss)
    
    metric(outputs, labels)
    
    
  return losses(), metric

# %%
def test_classifier_epoch(epoch):
  classifier.eval()
  metric = AccumulatedAccuracyMetric()
  losses = RunningAverage()
  for idx, (data, labels) in enumerate(test_loader):
    data= data.to(device)
    labels = labels.to(device)
    
    
    recon_batch, mu, logvar = model(data)
    ## classifier, pass latent vector
    outputs = classifier(mu)
    classifier_loss = criterion(outputs, labels)
    
    classifier_loss /= data.size(0)
    losses.update(classifier_loss)
    
    metric(outputs, labels)
    
    
  return losses(), metric

# %%
train_losses = []
train_accuracy = []
test_losses = []
test_accuracy = []
n_epochs = 20
for epoch in range(1, n_epochs):
  
  # Train stage
  train_loss, metric = train_classifier_epoch(epoch)
  train_losses.append(train_loss)
  train_accuracy.append(metric.value())
  
  message = 'Epoch: {}/{}. Train set: Average loss: {:.4f}'.format(epoch + 1, n_epochs, train_loss)
  message += '\t Average Accuracy: \t{}: {}'.format(metric.name(), metric.value())
  print(message)
  
  val_loss, metrics = test_classifier_epoch(epoch)
  test_losses.append(val_loss)
  test_accuracy.append(metrics.value())
  
  message += '\nEpoch: {}/{}. Test set: Average loss: {:.4f}'.format(epoch + 1, n_epochs,
                                                                                 val_loss)
  
  message += '\t Average Accuracy: \t{}: {}'.format(metrics.name(), metrics.value())

  
  print(message)
# Out:
# Epoch: 2/20. Train set: Average loss: 0.0004	 Average Accuracy: 	Accuracy: 98.11666666666666
# Epoch: 2/20. Train set: Average loss: 0.0004	 Average Accuracy: 	Accuracy: 98.11666666666666
# Epoch: 2/20. Test set: Average loss: 0.0007	 Average Accuracy: 	Accuracy: 97.6
# Epoch: 3/20. Train set: Average loss: 0.0004	 Average Accuracy: 	Accuracy: 98.395
# Epoch: 3/20. Train set: Average loss: 0.0004	 Average Accuracy: 	Accuracy: 98.395
# Epoch: 3/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.86
# Epoch: 4/20. Train set: Average loss: 0.0003	 Average Accuracy: 	Accuracy: 98.6
# Epoch: 4/20. Train set: Average loss: 0.0003	 Average Accuracy: 	Accuracy: 98.6
# Epoch: 4/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.58
# Epoch: 5/20. Train set: Average loss: 0.0003	 Average Accuracy: 	Accuracy: 98.68333333333334
# Epoch: 5/20. Train set: Average loss: 0.0003	 Average Accuracy: 	Accuracy: 98.68333333333334
# Epoch: 5/20. Test set: Average loss: 0.0007	 Average Accuracy: 	Accuracy: 97.75
# Epoch: 6/20. Train set: Average loss: 0.0003	 Average Accuracy: 	Accuracy: 98.73833333333333
# Epoch: 6/20. Train set: Average loss: 0.0003	 Average Accuracy: 	Accuracy: 98.73833333333333
# Epoch: 6/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.83
# Epoch: 7/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 98.96833333333333
# Epoch: 7/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 98.96833333333333
# Epoch: 7/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.85
# Epoch: 8/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.04666666666667
# Epoch: 8/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.04666666666667
# Epoch: 8/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.74
# Epoch: 9/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.15333333333334
# Epoch: 9/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.15333333333334
# Epoch: 9/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.67
# Epoch: 10/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.275
# Epoch: 10/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.275
# Epoch: 10/20. Test set: Average loss: 0.0006	 Average Accuracy: 	Accuracy: 97.8
# Epoch: 11/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.31333333333333
# Epoch: 11/20. Train set: Average loss: 0.0002	 Average Accuracy: 	Accuracy: 99.31333333333333
# Epoch: 11/20. Test set: Average loss: 0.0008	 Average Accuracy: 	Accuracy: 97.72
# Epoch: 12/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.37333333333333
# Epoch: 12/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.37333333333333
# Epoch: 12/20. Test set: Average loss: 0.0007	 Average Accuracy: 	Accuracy: 97.67
# Epoch: 13/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.38166666666666
# Epoch: 13/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.38166666666666
# Epoch: 13/20. Test set: Average loss: 0.0007	 Average Accuracy: 	Accuracy: 97.9
# Epoch: 14/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.53
# Epoch: 14/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.53
# Epoch: 14/20. Test set: Average loss: 0.0008	 Average Accuracy: 	Accuracy: 97.71
# Epoch: 15/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.48166666666667
# Epoch: 15/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.48166666666667
# Epoch: 15/20. Test set: Average loss: 0.0008	 Average Accuracy: 	Accuracy: 97.57
# Epoch: 16/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.51166666666667
# Epoch: 16/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.51166666666667
# Epoch: 16/20. Test set: Average loss: 0.0009	 Average Accuracy: 	Accuracy: 97.78
# Epoch: 17/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.52833333333334
# Epoch: 17/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.52833333333334
# Epoch: 17/20. Test set: Average loss: 0.0008	 Average Accuracy: 	Accuracy: 97.91
# Epoch: 18/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.61833333333334
# Epoch: 18/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.61833333333334
# Epoch: 18/20. Test set: Average loss: 0.0011	 Average Accuracy: 	Accuracy: 97.91
# Epoch: 19/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.625
# Epoch: 19/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.625
# Epoch: 19/20. Test set: Average loss: 0.0008	 Average Accuracy: 	Accuracy: 97.82
# Epoch: 20/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.78666666666666
# Epoch: 20/20. Train set: Average loss: 0.0001	 Average Accuracy: 	Accuracy: 99.78666666666666
# Epoch: 20/20. Test set: Average loss: 0.0011	 Average Accuracy: 	Accuracy: 97.79

# %%
plt.plot(range(n_epochs-1),train_losses)
plt.plot(range(n_epochs-1),test_losses)
plt.legend(["Train loss","Test loss"])
plt.show()

# %%
plt.plot(range(n_epochs-1),train_accuracy)
plt.plot(range(n_epochs-1),test_accuracy)
plt.legend(["Train accuracy","Test accuracy"])


plt.show()

# %%
### Plot TSNE for latent space
# Show dataset images with T-sne projection of latent space encoding
import seaborn as sns
palette = np.array(sns.color_palette("hls", 10))
def visualize_tsne_of_input(X, labels, model, name):
    # Compute latent space representation
    print("Computing latent space projection...")
    
    X_encoded, _ = model.encode(X)
    
    # Compute t-SNE embedding of latent space
    tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
    X_tsne = tsne.fit_transform(X_encoded.data.detach().cpu())

    # Plot images according to t-sne embedding
    fig, ax = plt.subplots()
    plt.scatter(X_tsne[:,0], X_tsne[:,1],c=[palette[i] for i in labels])
    path = f'./traverse/latent_space_{epoch}.png' 
    fig.savefig(path, dpi=fig.dpi)
    
visualize_tsne_of_input(test_data[:10000].to(device),test_labels[:10000].to(device),model,epoch)
# Out:
# Computing latent space projection...
